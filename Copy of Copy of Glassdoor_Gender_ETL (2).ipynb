# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jsonpath_ng
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting ply (from jsonpath_ng)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)
# Installing collected packages: ply, jsonpath_ng
# Successfully installed jsonpath_ng-1.5.3 ply-3.11

# %%
import os
import json
import numpy as np 
import pandas as pd 
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# # Source to Target Mapping - OOP Approach for Single Table

# %% [markdown]
# ### Data

# %%
import json
with open("Glassdoor Gender.json", "r") as file:
    data = json.load(file)
    for item in data:
        item["ID employee"] = str(item["ID employee"])
data[:10]
# Out:
# [{'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 18,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Operations',
#   'Seniority': 2,
#   'Salary($)': '42,363',
#   'Bonus($)': '9,938',
#   'Require-level': 'Junior',
#   'ID employee': '6789'},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 19,
#   'PerfEval': 4,
#   'Education': 'PhD',
#   'Dept': 'Administration',
#   'Seniority': 5,
#   'Salary($)': '90,208',
#   'Bonus($)': '9,268',
#   'Require-level': 'medium',
#   'ID employee': '6790'},
#  {'JobTitle': 'IT',
#   'Gender': 'Female',
#   'Age': 20,
#   'PerfEval': 5,
#   'Education': 'PhD',
#   'Dept': 'Operations',
#   'Seniority': 4,
#   'Salary($)': '70,890',
#   'Bonus($)': '10,126',
#   'Require-level': 'medium',
#   'ID employee': '6791'},
#  {'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 20,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Sales',
#   'Seniority': 4,
#   'Salary($)': '67,585',
#   'Bonus($)': '10,541',
#   'Require-level': 'medium',
#   'ID employee': '6792'},
#  {'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 33,
#   'PerfEval': 5,
#   'Education': 'High School',
#   'Dept': 'Engineering',
#   'Seniority': 5,
#   'Salary($)': '112,976',
#   'Bonus($)': '9,836',
#   'Require-level': 'medium',
#   'ID employee': '6793'},
#  {'JobTitle': 'Sales Associate',
#   'Gender': 'Female',
#   'Age': 35,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Engineering',
#   'Seniority': 5,
#   'Salary($)': '106,524',
#   'Bonus($)': '9,941',
#   'Require-level': 'medium',
#   'ID employee': '6794'},
#  {'JobTitle': 'Driver',
#   'Gender': 'Female',
#   'Age': 18,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Management',
#   'Seniority': 3,
#   'Salary($)': '62,759',
#   'Bonus($)': '10,124',
#   'Require-level': 'medium',
#   'ID employee': '6795'},
#  {'JobTitle': 'Financial Analyst',
#   'Gender': 'Female',
#   'Age': 19,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Sales',
#   'Seniority': 3,
#   'Salary($)': '84,007',
#   'Bonus($)': '8,990',
#   'Require-level': 'medium',
#   'ID employee': '6796'},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 30,
#   'PerfEval': 5,
#   'Education': 'Masters',
#   'Dept': 'Administration',
#   'Seniority': 5,
#   'Salary($)': '86,220',
#   'Bonus($)': '9,583',
#   'Require-level': 'medium',
#   'ID employee': '6797'},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 35,
#   'PerfEval': 5,
#   'Education': 'PhD',
#   'Dept': 'Operations',
#   'Seniority': 4,
#   'Salary($)': '95,584',
#   'Bonus($)': '9,745',
#   'Require-level': 'medium',
#   'ID employee': '6798'}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    # add here any masks you want
    CLEAN_STRING = ".strip().lower()" 
    CAPITAL_LETTER = ".strip().lower().title()"
    CLEAN_NUM = ""

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        self.add_source(1, "JobTitle", "str")
        self.add_destination(1, "JobTitle", "str")
        self.add_transform(1, "CLEAN_STRING")
        self.add_mapping(1, 1, 1, 1)
        self.add_source(2, "Gender", "str")
        self.add_destination(2, "Gender", "str")
        self.add_transform(2, "CLEAN_STRING")
        self.add_mapping(2, 2, 2, 2)
        self.add_source(3, "Age", "int")
        self.add_destination(3, "Age", "float")
        self.add_transform(3, "CLEAN_NUM")
        self.add_mapping(3, 3, 3, 3)
        self.add_source(4, "PerfEval", "int")
        self.add_destination(4, "PerfEval", "float")
        self.add_transform(4, "CLEAN_NUM")
        self.add_mapping(4, 4, 4, 4)
        self.add_source(5, "Education", "str")
        self.add_destination(5, "Education", "str")
        self.add_transform(5, "CLEAN_STRING")
        self.add_mapping(5, 5, 5, 5)
        self.add_source(6, "Dept", "str")
        self.add_destination(6, "Dept", "str")
        self.add_transform(6, "CLEAN_STRING")
        self.add_mapping(6, 6, 6, 6)
        
        

    
    def add_source(self, id, field, typ):
            self.db["source"].append({
                "id": id,
                "source_field_name": field,
                "source_field_mapping": field,
                "source_field_type": typ,
                "is_required": True,
            })
    
    def add_destination(self, id, field, typ):
        self.db["destination"].append({
            "id": id,
            "destination_field_name": field,
            "destination_field_mapping": field,
            "destination_field_type": typ,
            "default_value": "n/a", 
        })

    def add_transform(self, id, mask):
        self.db["transform"].append({
            "id": id,
            "transform_mask": mask,
        })

    def add_mapping(self, id, source, dest, transform):
      self.db["mapping"].append({
          "id": id,
          "mapping_source": source,
          "mapping_destination": dest,
          "mapping_transform": transform,
        })


    @property
    def get_data_source_target_mapping(self):
      return self.db

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'software engineer', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 25.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 25.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 40.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'software engineer', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 61.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 64.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 64.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'software engineer', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 61.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 65.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 40.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 65.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 5.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 5.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 59.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 54.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'software engineer', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'software engineer', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 60.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 31.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 5.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 38.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 5.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 56.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 61.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 22.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 4.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 4.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 1.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 49.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 37.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 52.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 1.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 40.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 41.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 29.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 54.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 64.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 30.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 25.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 65.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 23.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 18.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 39.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 42.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 35.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 50.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 59.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 3.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 20.0, 'PerfEval': 1.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 46.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 26.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 32.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'sales'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'engineering'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'manager', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 44.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 53.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 56.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 4.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 36.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 21.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 28.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 27.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 43.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 60.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 40.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 60.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 61.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 1.0, 'Education': 'college', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 3.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 2.0, 'Education': 'masters', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 19.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'operations'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'driver', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 3.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 57.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'management'}
# {'JobTitle': 'data scientist', 'Gender': 'female', 'Age': 51.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'warehouse associate', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 1.0, 'Education': 'masters', 'Dept': 'management'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 24.0, 'PerfEval': 1.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 58.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'sales'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 33.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'administration'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 34.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'operations'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 55.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'administration'}
# {'JobTitle': 'sales associate', 'Gender': 'female', 'Age': 47.0, 'PerfEval': 1.0, 'Education': 'phd', 'Dept': 'engineering'}
# {'JobTitle': 'it', 'Gender': 'female', 'Age': 45.0, 'PerfEval': 2.0, 'Education': 'phd', 'Dept': 'sales'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 48.0, 'PerfEval': 2.0, 'Education': 'high school', 'Dept': 'administration'}
# {'JobTitle': 'marketing associate', 'Gender': 'female', 'Age': 62.0, 'PerfEval': 3.0, 'Education': 'masters', 'Dept': 'engineering'}
# {'JobTitle': 'financial analyst', 'Gender': 'female', 'Age': 54.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'sales'}
# {'JobTitle': 'graphic designer', 'Gender': 'female', 'Age': 63.0, 'PerfEval': 2.0, 'Education': 'college', 'Dept': 'operations'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-5ea339026ff0> in <cell line: 2>()
#       2 for item in data:
#       3     helper = STTM(input_json=item)
# ----> 4     response = helper.get_transformed_data()
#       5     transformed_data.append(response)
#       6     print(response)
#
# <ipython-input-25-d029815cb477> in get_transformed_data(self)
#      42                     json_path=mapping_source_data.get("source_field_mapping"),
#      43                     json_data=self.input_json
# ---> 44                 ).get()
#      45
#      46                 """check the data type for source if matches with what we have """
#
# <ipython-input-24-0cd1d4b5f2bc> in get(self)
#       5
#       6     def get(self):
# ----> 7         jsonpath_expression = parse(self.json_path)
#       8         match = jsonpath_expression.find(self.json_data)
#       9         source_data_value = match[0].value
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse(string)
#      19
#      20 def parse(string):
# ---> 21     return JsonPathParser().parse(string)
#      22
#      23
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse(self, string, lexer)
#      42     def parse(self, string, lexer = None):
#      43         lexer = lexer or self.lexer_class()
# ---> 44         return self.parse_token_stream(lexer.tokenize(string))
#      45
#      46     def parse_token_stream(self, token_iterator, start_symbol='jsonpath'):
#
# /usr/local/lib/python3.10/dist-packages/jsonpath_ng/parser.py in parse_token_stream(self, token_iterator, start_symbol)
#      57
#      58         # And we regenerate the parse table every time; it doesn't actually take that long!
# ---> 59         new_parser = ply.yacc.yacc(module=self,
#      60                                    debug=self.debug,
#      61                                    tabmodule = parsing_table_module,
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in yacc(method, debug, module, tabmodule, start, check_recursion, optimize, write_tables, debugfile, outputdir, debuglog, errorlog, picklefile)
#    3436         errorlog.debug('Generating %s tables', method)
#    3437
# -> 3438     lr = LRGeneratedTable(grammar, method, debuglog)
#    3439
#    3440     if debug:
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in __init__(self, grammar, method, log)
#    2133         self.grammar.compute_first()
#    2134         self.grammar.compute_follow()
# -> 2135         self.lr_parse_table()
#    2136
#    2137     # Compute the LR(0) closure operation on I, where I is a set of LR(0) items.
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in lr_parse_table(self)
#    2708                         nkeys[s] = None
#    2709             for n in nkeys:
# -> 2710                 g = self.lr0_goto(I, n)
#    2711                 j = self.lr0_cidhash.get(id(g), -1)
#    2712                 if j >= 0:
#
# /usr/local/lib/python3.10/dist-packages/ply/yacc.py in lr0_goto(self, I, x)
#    2165     def lr0_goto(self, I, x):
#    2166         # First we look for a previously cached entry
# -> 2167         g = self.lr_goto_cache.get((id(I), x))
#    2168         if g:
#    2169             return g
#
# KeyboardInterrupt:

# %%
pd.DataFrame(transformed_data)
# Out:
#       id    Bonus
# 0   6789   9938.0
# 1   6790   9268.0
# 2   6791  10126.0
# 3   6792  10541.0
# 4   6793   9836.0
# ..   ...      ...
# 94  6886   7567.0
# 95  6887   7169.0
# 96  6888   7392.0
# 97  6889   7285.0
# 98  6890   7513.0
#
# [99 rows x 2 columns]
