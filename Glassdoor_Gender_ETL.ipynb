# %%
# !pip install jsonpath_ng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jsonpath_ng in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: ply in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (3.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonpath_ng) (1.16.0)

# %%
import os
import json
import numpy as np 
import pandas as pd 
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# # Source to Target Mapping - OOP Approach for Single Table

# %% [markdown]
# ### Data

# %%
import json
with open("Glassdoor Gender.json", "r") as file:
    data = json.load(file)
    for item in data:
        item["JobTitle"] = str(item["JobTitle"])
data[:10]
# Out:
# [{'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 18,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Operations',
#   'Seniority': 2,
#   'Salary': 42363,
#   'Bonus': 9938,
#   'Require_level': 'Junior',
#   'ID_employee': 6789},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 19,
#   'PerfEval': 4,
#   'Education': 'PhD',
#   'Dept': 'Administration',
#   'Seniority': 5,
#   'Salary': 90208,
#   'Bonus': 9268,
#   'Require_level': 'medium',
#   'ID_employee': 6790},
#  {'JobTitle': 'IT',
#   'Gender': 'Female',
#   'Age': 20,
#   'PerfEval': 5,
#   'Education': 'PhD',
#   'Dept': 'Operations',
#   'Seniority': 4,
#   'Salary': 70890,
#   'Bonus': 10126,
#   'Require_level': 'medium',
#   'ID_employee': 6791},
#  {'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 20,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Sales',
#   'Seniority': 4,
#   'Salary': 67585,
#   'Bonus': 10541,
#   'Require_level': 'medium',
#   'ID_employee': 6792},
#  {'JobTitle': 'Graphic Designer',
#   'Gender': 'Female',
#   'Age': 33,
#   'PerfEval': 5,
#   'Education': 'High School',
#   'Dept': 'Engineering',
#   'Seniority': 5,
#   'Salary': 112976,
#   'Bonus': 9836,
#   'Require_level': 'medium',
#   'ID_employee': 6793},
#  {'JobTitle': 'Sales Associate',
#   'Gender': 'Female',
#   'Age': 35,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Engineering',
#   'Seniority': 5,
#   'Salary': 106524,
#   'Bonus': 9941,
#   'Require_level': 'medium',
#   'ID_employee': 6794},
#  {'JobTitle': 'Driver',
#   'Gender': 'Female',
#   'Age': 18,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Management',
#   'Seniority': 3,
#   'Salary': 62759,
#   'Bonus': 10124,
#   'Require_level': 'medium',
#   'ID_employee': 6795},
#  {'JobTitle': 'Financial Analyst',
#   'Gender': 'Female',
#   'Age': 19,
#   'PerfEval': 5,
#   'Education': 'College',
#   'Dept': 'Sales',
#   'Seniority': 3,
#   'Salary': 84007,
#   'Bonus': 8990,
#   'Require_level': 'medium',
#   'ID_employee': 6796},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 30,
#   'PerfEval': 5,
#   'Education': 'Masters',
#   'Dept': 'Administration',
#   'Seniority': 5,
#   'Salary': 86220,
#   'Bonus': 9583,
#   'Require_level': 'medium',
#   'ID_employee': 6797},
#  {'JobTitle': 'Warehouse Associate',
#   'Gender': 'Female',
#   'Age': 35,
#   'PerfEval': 5,
#   'Education': 'PhD',
#   'Dept': 'Operations',
#   'Seniority': 4,
#   'Salary': 95584,
#   'Bonus': 9745,
#   'Require_level': 'medium',
#   'ID_employee': 6798}]

# %% [markdown]
# ###  Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# ### Transform Operations
# inherithed from Enum - class that automatic enumrate the variables

# %%
class TransformMask(Enum):
    # add here any masks you want
    CLEAN_STRING = ".strip().lower()" 
    CAPITAL_LETTER = ".strip().lower().title()"
    CLEAN_NUM = ""

# %% [markdown]
# ### Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        self.add_source(1, "JobTitle", "str")
        self.add_destination(1, "JobTitle", "str")
        self.add_transform(1, "CLEAN_STRING")
        self.add_mapping(1, 1, 1, 1)
        self.add_source(8, "Salary", "int")
        self.add_destination(8, "Salary", "float")
        self.add_transform(8, "CLEAN_NUM")
        self.add_mapping(8, 8, 8, 8)
        self.add_source(9, "Bonus", "int")
        self.add_destination(9, "Bonus", "float")
        self.add_transform(9, "CLEAN_NUM")
        self.add_mapping(9, 9, 9, 9)
        self.add_source(11, "ID_employee", "int")
        self.add_destination(11, "ID_employee", "float")
        self.add_transform(11, "CLEAN_NUM")
        self.add_mapping(11, 11, 11, 11)
        

    
    def add_source(self, id, field, typ):
            self.db["source"].append({
                "id": id,
                "source_field_name": field,
                "source_field_mapping": field,
                "source_field_type": typ,
                "is_required": True,
            })
    
    def add_destination(self, id, field, typ):
        self.db["destination"].append({
            "id": id,
            "destination_field_name": field,
            "destination_field_mapping": field,
            "destination_field_type": typ,
            "default_value": "n/a", 
        })

    def add_transform(self, id, mask):
        self.db["transform"].append({
            "id": id,
            "transform_mask": mask,
        })

    def add_mapping(self, id, source, dest, transform):
      self.db["mapping"].append({
          "id": id,
          "mapping_source": source,
          "mapping_destination": dest,
          "mapping_transform": transform,
        })


    @property
    def get_data_source_target_mapping(self):
      return self.db

# %% [markdown]
# ### Source class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# ### Target class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Transform Class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# ### Mapping class
#
# Inherited from Interface for the common methods and from Database for common variables

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# ### Format Class - JSON
#
# Search the source data value inside a JSON file

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# ### Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")

            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
# Out:
# {'JobTitle': 'graphic designer', 'Salary': 42363.0, 'Bonus': 9938.0, 'ID_employee': 6789.0}
# {'JobTitle': 'warehouse associate', 'Salary': 90208.0, 'Bonus': 9268.0, 'ID_employee': 6790.0}
# {'JobTitle': 'it', 'Salary': 70890.0, 'Bonus': 10126.0, 'ID_employee': 6791.0}
# {'JobTitle': 'graphic designer', 'Salary': 67585.0, 'Bonus': 10541.0, 'ID_employee': 6792.0}
# {'JobTitle': 'graphic designer', 'Salary': 112976.0, 'Bonus': 9836.0, 'ID_employee': 6793.0}
# {'JobTitle': 'sales associate', 'Salary': 106524.0, 'Bonus': 9941.0, 'ID_employee': 6794.0}
# {'JobTitle': 'driver', 'Salary': 62759.0, 'Bonus': 10124.0, 'ID_employee': 6795.0}
# {'JobTitle': 'financial analyst', 'Salary': 84007.0, 'Bonus': 8990.0, 'ID_employee': 6796.0}
# {'JobTitle': 'warehouse associate', 'Salary': 86220.0, 'Bonus': 9583.0, 'ID_employee': 6797.0}
# {'JobTitle': 'warehouse associate', 'Salary': 95584.0, 'Bonus': 9745.0, 'ID_employee': 6798.0}
# {'JobTitle': 'marketing associate', 'Salary': 73357.0, 'Bonus': 10334.0, 'ID_employee': 6799.0}
# {'JobTitle': 'financial analyst', 'Salary': 88422.0, 'Bonus': 10768.0, 'ID_employee': 6800.0}
# {'JobTitle': 'warehouse associate', 'Salary': 99545.0, 'Bonus': 9949.0, 'ID_employee': 6801.0}
# {'JobTitle': 'data scientist', 'Salary': 92067.0, 'Bonus': 9838.0, 'ID_employee': 6802.0}
# {'JobTitle': 'driver', 'Salary': 72038.0, 'Bonus': 9031.0, 'ID_employee': 6803.0}
# {'JobTitle': 'graphic designer', 'Salary': 71182.0, 'Bonus': 10015.0, 'ID_employee': 6804.0}
# {'JobTitle': 'it', 'Salary': 112392.0, 'Bonus': 10504.0, 'ID_employee': 6805.0}
# {'JobTitle': 'marketing associate', 'Salary': 80306.0, 'Bonus': 9233.0, 'ID_employee': 6806.0}
# {'JobTitle': 'data scientist', 'Salary': 74523.0, 'Bonus': 9972.0, 'ID_employee': 6807.0}
# {'JobTitle': 'data scientist', 'Salary': 113252.0, 'Bonus': 10139.0, 'ID_employee': 6808.0}
# {'JobTitle': 'it', 'Salary': 84638.0, 'Bonus': 9409.0, 'ID_employee': 6809.0}
# {'JobTitle': 'data scientist', 'Salary': 70643.0, 'Bonus': 10033.0, 'ID_employee': 6810.0}
# {'JobTitle': 'graphic designer', 'Salary': 74167.0, 'Bonus': 10346.0, 'ID_employee': 6811.0}
# {'JobTitle': 'it', 'Salary': 102120.0, 'Bonus': 10215.0, 'ID_employee': 6812.0}
# {'JobTitle': 'marketing associate', 'Salary': 97376.0, 'Bonus': 9564.0, 'ID_employee': 6813.0}
# {'JobTitle': 'data scientist', 'Salary': 89415.0, 'Bonus': 9654.0, 'ID_employee': 6814.0}
# {'JobTitle': 'software engineer', 'Salary': 88037.0, 'Bonus': 8949.0, 'ID_employee': 6815.0}
# {'JobTitle': 'data scientist', 'Salary': 71105.0, 'Bonus': 8623.0, 'ID_employee': 6816.0}
# {'JobTitle': 'driver', 'Salary': 62692.0, 'Bonus': 8886.0, 'ID_employee': 6817.0}
# {'JobTitle': 'data scientist', 'Salary': 71193.0, 'Bonus': 8331.0, 'ID_employee': 6818.0}
# {'JobTitle': 'marketing associate', 'Salary': 76286.0, 'Bonus': 9479.0, 'ID_employee': 6819.0}
# {'JobTitle': 'warehouse associate', 'Salary': 82453.0, 'Bonus': 9564.0, 'ID_employee': 6820.0}
# {'JobTitle': 'sales associate', 'Salary': 83034.0, 'Bonus': 8841.0, 'ID_employee': 6821.0}
# {'JobTitle': 'warehouse associate', 'Salary': 127085.0, 'Bonus': 9687.0, 'ID_employee': 6822.0}
# {'JobTitle': 'sales associate', 'Salary': 52633.0, 'Bonus': 9516.0, 'ID_employee': 6823.0}
# {'JobTitle': 'warehouse associate', 'Salary': 101154.0, 'Bonus': 10324.0, 'ID_employee': 6824.0}
# {'JobTitle': 'financial analyst', 'Salary': 113640.0, 'Bonus': 8762.0, 'ID_employee': 6825.0}
# {'JobTitle': 'marketing associate', 'Salary': 46263.0, 'Bonus': 9432.0, 'ID_employee': 6826.0}
# {'JobTitle': 'warehouse associate', 'Salary': 74938.0, 'Bonus': 8234.0, 'ID_employee': 6827.0}
# {'JobTitle': 'marketing associate', 'Salary': 103384.0, 'Bonus': 9168.0, 'ID_employee': 6828.0}
# {'JobTitle': 'warehouse associate', 'Salary': 77584.0, 'Bonus': 9798.0, 'ID_employee': 6829.0}
# {'JobTitle': 'warehouse associate', 'Salary': 80192.0, 'Bonus': 8747.0, 'ID_employee': 6830.0}
# {'JobTitle': 'data scientist', 'Salary': 46693.0, 'Bonus': 8457.0, 'ID_employee': 6831.0}
# {'JobTitle': 'it', 'Salary': 88152.0, 'Bonus': 8857.0, 'ID_employee': 6832.0}
# {'JobTitle': 'data scientist', 'Salary': 127156.0, 'Bonus': 9979.0, 'ID_employee': 6833.0}
# {'JobTitle': 'financial analyst', 'Salary': 92622.0, 'Bonus': 8509.0, 'ID_employee': 6834.0}
# {'JobTitle': 'marketing associate', 'Salary': 51331.0, 'Bonus': 9130.0, 'ID_employee': 6835.0}
# {'JobTitle': 'driver', 'Salary': 77032.0, 'Bonus': 8725.0, 'ID_employee': 6836.0}
# {'JobTitle': 'financial analyst', 'Salary': 146190.0, 'Bonus': 8961.0, 'ID_employee': 6837.0}
# {'JobTitle': 'graphic designer', 'Salary': 96045.0, 'Bonus': 9129.0, 'ID_employee': 6838.0}
# {'JobTitle': 'marketing associate', 'Salary': 96061.0, 'Bonus': 9093.0, 'ID_employee': 6839.0}
# {'JobTitle': 'warehouse associate', 'Salary': 111342.0, 'Bonus': 10122.0, 'ID_employee': 6840.0}
# {'JobTitle': 'financial analyst', 'Salary': 117554.0, 'Bonus': 8369.0, 'ID_employee': 6841.0}
# {'JobTitle': 'financial analyst', 'Salary': 109369.0, 'Bonus': 10052.0, 'ID_employee': 6842.0}
# {'JobTitle': 'warehouse associate', 'Salary': 92358.0, 'Bonus': 9611.0, 'ID_employee': 6843.0}
# {'JobTitle': 'financial analyst', 'Salary': 91978.0, 'Bonus': 8647.0, 'ID_employee': 6844.0}
# {'JobTitle': 'marketing associate', 'Salary': 89822.0, 'Bonus': 8818.0, 'ID_employee': 6845.0}
# {'JobTitle': 'warehouse associate', 'Salary': 87684.0, 'Bonus': 8645.0, 'ID_employee': 6846.0}
# {'JobTitle': 'marketing associate', 'Salary': 62040.0, 'Bonus': 8056.0, 'ID_employee': 6847.0}
# {'JobTitle': 'sales associate', 'Salary': 84132.0, 'Bonus': 7204.0, 'ID_employee': 6848.0}
# {'JobTitle': 'financial analyst', 'Salary': 88047.0, 'Bonus': 8459.0, 'ID_employee': 6849.0}
# {'JobTitle': 'driver', 'Salary': 65012.0, 'Bonus': 8357.0, 'ID_employee': 6850.0}
# {'JobTitle': 'marketing associate', 'Salary': 59251.0, 'Bonus': 8596.0, 'ID_employee': 6851.0}
# {'JobTitle': 'graphic designer', 'Salary': 78462.0, 'Bonus': 8743.0, 'ID_employee': 6852.0}
# {'JobTitle': 'driver', 'Salary': 42722.0, 'Bonus': 8515.0, 'ID_employee': 6853.0}
# {'JobTitle': 'marketing associate', 'Salary': 63695.0, 'Bonus': 8897.0, 'ID_employee': 6854.0}
# {'JobTitle': 'it', 'Salary': 53956.0, 'Bonus': 9454.0, 'ID_employee': 6855.0}
# {'JobTitle': 'it', 'Salary': 108495.0, 'Bonus': 8668.0, 'ID_employee': 6856.0}
# {'JobTitle': 'financial analyst', 'Salary': 87608.0, 'Bonus': 7511.0, 'ID_employee': 6857.0}
# {'JobTitle': 'marketing associate', 'Salary': 57469.0, 'Bonus': 7539.0, 'ID_employee': 6858.0}
# {'JobTitle': 'driver', 'Salary': 91049.0, 'Bonus': 10375.0, 'ID_employee': 6859.0}
# {'JobTitle': 'manager', 'Salary': 98519.0, 'Bonus': 8943.0, 'ID_employee': 6860.0}
# {'JobTitle': 'marketing associate', 'Salary': 91713.0, 'Bonus': 7627.0, 'ID_employee': 6861.0}
# {'JobTitle': 'warehouse associate', 'Salary': 88994.0, 'Bonus': 8873.0, 'ID_employee': 6862.0}
# {'JobTitle': 'financial analyst', 'Salary': 113180.0, 'Bonus': 9089.0, 'ID_employee': 6863.0}
# {'JobTitle': 'software engineer', 'Salary': 103763.0, 'Bonus': 8383.0, 'ID_employee': 6864.0}
# {'JobTitle': 'warehouse associate', 'Salary': 64844.0, 'Bonus': 9042.0, 'ID_employee': 6865.0}
# {'JobTitle': 'driver', 'Salary': 129132.0, 'Bonus': 8472.0, 'ID_employee': 6866.0}
# {'JobTitle': 'warehouse associate', 'Salary': 93470.0, 'Bonus': 8578.0, 'ID_employee': 6867.0}
# {'JobTitle': 'graphic designer', 'Salary': 66529.0, 'Bonus': 7067.0, 'ID_employee': 6868.0}
# {'JobTitle': 'data scientist', 'Salary': 100115.0, 'Bonus': 7679.0, 'ID_employee': 6869.0}
# {'JobTitle': 'warehouse associate', 'Salary': 86423.0, 'Bonus': 8058.0, 'ID_employee': 6870.0}
# {'JobTitle': 'data scientist', 'Salary': 133495.0, 'Bonus': 8552.0, 'ID_employee': 6871.0}
# {'JobTitle': 'sales associate', 'Salary': 84844.0, 'Bonus': 7205.0, 'ID_employee': 6872.0}
# {'JobTitle': 'graphic designer', 'Salary': 108241.0, 'Bonus': 8602.0, 'ID_employee': 6873.0}
# {'JobTitle': 'warehouse associate', 'Salary': 106478.0, 'Bonus': 8744.0, 'ID_employee': 6874.0}
# {'JobTitle': 'marketing associate', 'Salary': 46903.0, 'Bonus': 8130.0, 'ID_employee': 6875.0}
# {'JobTitle': 'marketing associate', 'Salary': 44325.0, 'Bonus': 8867.0, 'ID_employee': 6876.0}
# {'JobTitle': 'marketing associate', 'Salary': 60070.0, 'Bonus': 8273.0, 'ID_employee': 6877.0}
# {'JobTitle': 'it', 'Salary': 72542.0, 'Bonus': 8109.0, 'ID_employee': 6878.0}
# {'JobTitle': 'it', 'Salary': 80981.0, 'Bonus': 8201.0, 'ID_employee': 6879.0}
# {'JobTitle': 'it', 'Salary': 83499.0, 'Bonus': 8950.0, 'ID_employee': 6880.0}
# {'JobTitle': 'driver', 'Salary': 106788.0, 'Bonus': 8974.0, 'ID_employee': 6881.0}
# {'JobTitle': 'warehouse associate', 'Salary': 108922.0, 'Bonus': 8477.0, 'ID_employee': 6882.0}
# {'JobTitle': 'it', 'Salary': 127062.0, 'Bonus': 9619.0, 'ID_employee': 6883.0}
# {'JobTitle': 'marketing associate', 'Salary': 49830.0, 'Bonus': 8543.0, 'ID_employee': 6884.0}
# {'JobTitle': 'marketing associate', 'Salary': 82338.0, 'Bonus': 7414.0, 'ID_employee': 6885.0}
# {'JobTitle': 'marketing associate', 'Salary': 86036.0, 'Bonus': 7567.0, 'ID_employee': 6886.0}
# {'JobTitle': 'financial analyst', 'Salary': 100070.0, 'Bonus': 7169.0, 'ID_employee': 6887.0}
# {'JobTitle': 'sales associate', 'Salary': 129609.0, 'Bonus': 7392.0, 'ID_employee': 6888.0}
# {'JobTitle': 'driver', 'Salary': 72827.0, 'Bonus': 7285.0, 'ID_employee': 6889.0}
# {'JobTitle': 'graphic designer', 'Salary': 100416.0, 'Bonus': 7513.0, 'ID_employee': 6890.0}
# {'JobTitle': 'data scientist', 'Salary': 78623.0, 'Bonus': 9012.0, 'ID_employee': 6891.0}
# {'JobTitle': 'warehouse associate', 'Salary': 106158.0, 'Bonus': 7654.0, 'ID_employee': 6892.0}
# {'JobTitle': 'graphic designer', 'Salary': 89411.0, 'Bonus': 9522.0, 'ID_employee': 6893.0}
# {'JobTitle': 'marketing associate', 'Salary': 95687.0, 'Bonus': 7279.0, 'ID_employee': 6894.0}
# {'JobTitle': 'graphic designer', 'Salary': 120294.0, 'Bonus': 8090.0, 'ID_employee': 6895.0}
# {'JobTitle': 'financial analyst', 'Salary': 76773.0, 'Bonus': 7278.0, 'ID_employee': 6896.0}
# {'JobTitle': 'data scientist', 'Salary': 98010.0, 'Bonus': 8210.0, 'ID_employee': 6897.0}
# {'JobTitle': 'data scientist', 'Salary': 91099.0, 'Bonus': 8306.0, 'ID_employee': 6898.0}
# {'JobTitle': 'marketing associate', 'Salary': 128970.0, 'Bonus': 7346.0, 'ID_employee': 6899.0}
# {'JobTitle': 'warehouse associate', 'Salary': 121376.0, 'Bonus': 7832.0, 'ID_employee': 6900.0}
# {'JobTitle': 'driver', 'Salary': 64008.0, 'Bonus': 7185.0, 'ID_employee': 6901.0}
# {'JobTitle': 'financial analyst', 'Salary': 129406.0, 'Bonus': 7280.0, 'ID_employee': 6902.0}
# {'JobTitle': 'it', 'Salary': 54245.0, 'Bonus': 8245.0, 'ID_employee': 6903.0}
# {'JobTitle': 'marketing associate', 'Salary': 67530.0, 'Bonus': 9311.0, 'ID_employee': 6904.0}
# {'JobTitle': 'graphic designer', 'Salary': 81826.0, 'Bonus': 8375.0, 'ID_employee': 6905.0}
# {'JobTitle': 'software engineer', 'Salary': 65711.0, 'Bonus': 7789.0, 'ID_employee': 6906.0}
# {'JobTitle': 'driver', 'Salary': 73801.0, 'Bonus': 8317.0, 'ID_employee': 6907.0}
# {'JobTitle': 'sales associate', 'Salary': 93268.0, 'Bonus': 7657.0, 'ID_employee': 6908.0}
# {'JobTitle': 'graphic designer', 'Salary': 103133.0, 'Bonus': 7793.0, 'ID_employee': 6909.0}
# {'JobTitle': 'marketing associate', 'Salary': 69254.0, 'Bonus': 8609.0, 'ID_employee': 6910.0}
# {'JobTitle': 'data scientist', 'Salary': 97000.0, 'Bonus': 7757.0, 'ID_employee': 6911.0}
# {'JobTitle': 'financial analyst', 'Salary': 40341.0, 'Bonus': 7320.0, 'ID_employee': 6912.0}
# {'JobTitle': 'it', 'Salary': 102247.0, 'Bonus': 8307.0, 'ID_employee': 6913.0}
# {'JobTitle': 'warehouse associate', 'Salary': 92722.0, 'Bonus': 8010.0, 'ID_employee': 6914.0}
# {'JobTitle': 'sales associate', 'Salary': 72120.0, 'Bonus': 9084.0, 'ID_employee': 6915.0}
# {'JobTitle': 'warehouse associate', 'Salary': 62260.0, 'Bonus': 7740.0, 'ID_employee': 6916.0}
# {'JobTitle': 'data scientist', 'Salary': 84021.0, 'Bonus': 9111.0, 'ID_employee': 6917.0}
# {'JobTitle': 'warehouse associate', 'Salary': 37026.0, 'Bonus': 8636.0, 'ID_employee': 6918.0}
# {'JobTitle': 'data scientist', 'Salary': 55954.0, 'Bonus': 7999.0, 'ID_employee': 6919.0}
# {'JobTitle': 'graphic designer', 'Salary': 108820.0, 'Bonus': 7776.0, 'ID_employee': 6920.0}
# {'JobTitle': 'it', 'Salary': 100014.0, 'Bonus': 8621.0, 'ID_employee': 6921.0}
# {'JobTitle': 'sales associate', 'Salary': 108288.0, 'Bonus': 7491.0, 'ID_employee': 6922.0}
# {'JobTitle': 'financial analyst', 'Salary': 114007.0, 'Bonus': 9248.0, 'ID_employee': 6923.0}
# {'JobTitle': 'warehouse associate', 'Salary': 94973.0, 'Bonus': 7885.0, 'ID_employee': 6924.0}
# {'JobTitle': 'it', 'Salary': 37780.0, 'Bonus': 8443.0, 'ID_employee': 6925.0}
# {'JobTitle': 'it', 'Salary': 121210.0, 'Bonus': 7949.0, 'ID_employee': 6926.0}
# {'JobTitle': 'graphic designer', 'Salary': 95169.0, 'Bonus': 7415.0, 'ID_employee': 6927.0}
# {'JobTitle': 'driver', 'Salary': 75901.0, 'Bonus': 7402.0, 'ID_employee': 6928.0}
# {'JobTitle': 'sales associate', 'Salary': 92276.0, 'Bonus': 9551.0, 'ID_employee': 6929.0}
# {'JobTitle': 'driver', 'Salary': 92458.0, 'Bonus': 6966.0, 'ID_employee': 6930.0}
# {'JobTitle': 'marketing associate', 'Salary': 87435.0, 'Bonus': 9230.0, 'ID_employee': 6931.0}
# {'JobTitle': 'graphic designer', 'Salary': 130251.0, 'Bonus': 7750.0, 'ID_employee': 6932.0}
# {'JobTitle': 'manager', 'Salary': 106560.0, 'Bonus': 7257.0, 'ID_employee': 6933.0}
# {'JobTitle': 'warehouse associate', 'Salary': 56172.0, 'Bonus': 7739.0, 'ID_employee': 6934.0}
# {'JobTitle': 'marketing associate', 'Salary': 58807.0, 'Bonus': 7316.0, 'ID_employee': 6935.0}
# {'JobTitle': 'financial analyst', 'Salary': 126626.0, 'Bonus': 7144.0, 'ID_employee': 6936.0}
# {'JobTitle': 'manager', 'Salary': 104202.0, 'Bonus': 8456.0, 'ID_employee': 6937.0}
# {'JobTitle': 'driver', 'Salary': 78750.0, 'Bonus': 6666.0, 'ID_employee': 6938.0}
# {'JobTitle': 'warehouse associate', 'Salary': 93306.0, 'Bonus': 8265.0, 'ID_employee': 6939.0}
# {'JobTitle': 'sales associate', 'Salary': 56745.0, 'Bonus': 6495.0, 'ID_employee': 6940.0}
# {'JobTitle': 'data scientist', 'Salary': 59458.0, 'Bonus': 7939.0, 'ID_employee': 6941.0}
# {'JobTitle': 'driver', 'Salary': 71824.0, 'Bonus': 6397.0, 'ID_employee': 6942.0}
# {'JobTitle': 'warehouse associate', 'Salary': 91568.0, 'Bonus': 7139.0, 'ID_employee': 6943.0}
# {'JobTitle': 'marketing associate', 'Salary': 81995.0, 'Bonus': 7840.0, 'ID_employee': 6944.0}
# {'JobTitle': 'graphic designer', 'Salary': 66125.0, 'Bonus': 8465.0, 'ID_employee': 6945.0}
# {'JobTitle': 'sales associate', 'Salary': 98321.0, 'Bonus': 8980.0, 'ID_employee': 6946.0}
# {'JobTitle': 'manager', 'Salary': 155203.0, 'Bonus': 7808.0, 'ID_employee': 6947.0}
# {'JobTitle': 'data scientist', 'Salary': 73306.0, 'Bonus': 7765.0, 'ID_employee': 6948.0}
# {'JobTitle': 'warehouse associate', 'Salary': 76865.0, 'Bonus': 8145.0, 'ID_employee': 6949.0}
# {'JobTitle': 'graphic designer', 'Salary': 125770.0, 'Bonus': 8013.0, 'ID_employee': 6950.0}
# {'JobTitle': 'financial analyst', 'Salary': 119931.0, 'Bonus': 8400.0, 'ID_employee': 6951.0}
# {'JobTitle': 'marketing associate', 'Salary': 71794.0, 'Bonus': 6685.0, 'ID_employee': 6952.0}
# {'JobTitle': 'driver', 'Salary': 87998.0, 'Bonus': 7028.0, 'ID_employee': 6953.0}
# {'JobTitle': 'sales associate', 'Salary': 77275.0, 'Bonus': 7089.0, 'ID_employee': 6954.0}
# {'JobTitle': 'driver', 'Salary': 130720.0, 'Bonus': 7246.0, 'ID_employee': 6955.0}
# {'JobTitle': 'software engineer', 'Salary': 86675.0, 'Bonus': 7947.0, 'ID_employee': 6956.0}
# {'JobTitle': 'graphic designer', 'Salary': 56954.0, 'Bonus': 7550.0, 'ID_employee': 6957.0}
# {'JobTitle': 'software engineer', 'Salary': 112491.0, 'Bonus': 8727.0, 'ID_employee': 6958.0}
# {'JobTitle': 'marketing associate', 'Salary': 36548.0, 'Bonus': 8090.0, 'ID_employee': 6959.0}
# {'JobTitle': 'driver', 'Salary': 88781.0, 'Bonus': 6413.0, 'ID_employee': 6960.0}
# {'JobTitle': 'data scientist', 'Salary': 129226.0, 'Bonus': 6912.0, 'ID_employee': 6961.0}
# {'JobTitle': 'manager', 'Salary': 160614.0, 'Bonus': 8354.0, 'ID_employee': 6962.0}
# {'JobTitle': 'sales associate', 'Salary': 89570.0, 'Bonus': 7411.0, 'ID_employee': 6963.0}
# {'JobTitle': 'marketing associate', 'Salary': 73989.0, 'Bonus': 8780.0, 'ID_employee': 6964.0}
# {'JobTitle': 'financial analyst', 'Salary': 67762.0, 'Bonus': 7449.0, 'ID_employee': 6965.0}
# {'JobTitle': 'driver', 'Salary': 77751.0, 'Bonus': 6554.0, 'ID_employee': 6966.0}
# {'JobTitle': 'data scientist', 'Salary': 87150.0, 'Bonus': 6814.0, 'ID_employee': 6967.0}
# {'JobTitle': 'driver', 'Salary': 79291.0, 'Bonus': 5000.0, 'ID_employee': 6968.0}
# {'JobTitle': 'driver', 'Salary': 57070.0, 'Bonus': 6615.0, 'ID_employee': 6969.0}
# {'JobTitle': 'marketing associate', 'Salary': 102201.0, 'Bonus': 7640.0, 'ID_employee': 6970.0}
# {'JobTitle': 'marketing associate', 'Salary': 57782.0, 'Bonus': 7144.0, 'ID_employee': 6971.0}
# {'JobTitle': 'marketing associate', 'Salary': 71772.0, 'Bonus': 5764.0, 'ID_employee': 6972.0}
# {'JobTitle': 'marketing associate', 'Salary': 66438.0, 'Bonus': 6935.0, 'ID_employee': 6973.0}
# {'JobTitle': 'marketing associate', 'Salary': 79674.0, 'Bonus': 6993.0, 'ID_employee': 6974.0}
# {'JobTitle': 'marketing associate', 'Salary': 85161.0, 'Bonus': 6682.0, 'ID_employee': 6975.0}
# {'JobTitle': 'warehouse associate', 'Salary': 114479.0, 'Bonus': 6700.0, 'ID_employee': 6976.0}
# {'JobTitle': 'data scientist', 'Salary': 71946.0, 'Bonus': 6386.0, 'ID_employee': 6977.0}
# {'JobTitle': 'marketing associate', 'Salary': 62054.0, 'Bonus': 6955.0, 'ID_employee': 6978.0}
# {'JobTitle': 'warehouse associate', 'Salary': 64624.0, 'Bonus': 8253.0, 'ID_employee': 6979.0}
# {'JobTitle': 'sales associate', 'Salary': 105410.0, 'Bonus': 6363.0, 'ID_employee': 6980.0}
# {'JobTitle': 'warehouse associate', 'Salary': 90005.0, 'Bonus': 6631.0, 'ID_employee': 6981.0}
# {'JobTitle': 'marketing associate', 'Salary': 70374.0, 'Bonus': 7466.0, 'ID_employee': 6982.0}
# {'JobTitle': 'marketing associate', 'Salary': 104355.0, 'Bonus': 7555.0, 'ID_employee': 6983.0}
# {'JobTitle': 'it', 'Salary': 75811.0, 'Bonus': 5520.0, 'ID_employee': 6984.0}
# {'JobTitle': 'graphic designer', 'Salary': 107025.0, 'Bonus': 6577.0, 'ID_employee': 6985.0}
# {'JobTitle': 'data scientist', 'Salary': 40056.0, 'Bonus': 7632.0, 'ID_employee': 6986.0}
# {'JobTitle': 'it', 'Salary': 70846.0, 'Bonus': 7404.0, 'ID_employee': 6987.0}
# {'JobTitle': 'marketing associate', 'Salary': 79707.0, 'Bonus': 7196.0, 'ID_employee': 6988.0}
# {'JobTitle': 'financial analyst', 'Salary': 62377.0, 'Bonus': 6999.0, 'ID_employee': 6989.0}
# {'JobTitle': 'it', 'Salary': 75932.0, 'Bonus': 7003.0, 'ID_employee': 6990.0}
# {'JobTitle': 'marketing associate', 'Salary': 82755.0, 'Bonus': 7325.0, 'ID_employee': 6991.0}
# {'JobTitle': 'warehouse associate', 'Salary': 78021.0, 'Bonus': 6970.0, 'ID_employee': 6992.0}
# {'JobTitle': 'financial analyst', 'Salary': 116758.0, 'Bonus': 7744.0, 'ID_employee': 6993.0}
# {'JobTitle': 'marketing associate', 'Salary': 96500.0, 'Bonus': 8092.0, 'ID_employee': 6994.0}
# {'JobTitle': 'marketing associate', 'Salary': 49632.0, 'Bonus': 7169.0, 'ID_employee': 6995.0}
# {'JobTitle': 'driver', 'Salary': 76700.0, 'Bonus': 7242.0, 'ID_employee': 6996.0}
# {'JobTitle': 'graphic designer', 'Salary': 100516.0, 'Bonus': 6737.0, 'ID_employee': 6997.0}
# {'JobTitle': 'sales associate', 'Salary': 84935.0, 'Bonus': 6122.0, 'ID_employee': 6998.0}
# {'JobTitle': 'driver', 'Salary': 101249.0, 'Bonus': 7329.0, 'ID_employee': 6999.0}
# {'JobTitle': 'manager', 'Salary': 144146.0, 'Bonus': 6340.0, 'ID_employee': 7000.0}
# {'JobTitle': 'marketing associate', 'Salary': 69268.0, 'Bonus': 7106.0, 'ID_employee': 7001.0}
# {'JobTitle': 'sales associate', 'Salary': 127561.0, 'Bonus': 7552.0, 'ID_employee': 7002.0}
# {'JobTitle': 'marketing associate', 'Salary': 77223.0, 'Bonus': 5272.0, 'ID_employee': 7003.0}
# {'JobTitle': 'warehouse associate', 'Salary': 92080.0, 'Bonus': 6897.0, 'ID_employee': 7004.0}
# {'JobTitle': 'graphic designer', 'Salary': 118762.0, 'Bonus': 6545.0, 'ID_employee': 7005.0}
# {'JobTitle': 'sales associate', 'Salary': 85398.0, 'Bonus': 7113.0, 'ID_employee': 7006.0}
# {'JobTitle': 'data scientist', 'Salary': 123172.0, 'Bonus': 5797.0, 'ID_employee': 7007.0}
# {'JobTitle': 'data scientist', 'Salary': 107476.0, 'Bonus': 6182.0, 'ID_employee': 7008.0}
# {'JobTitle': 'marketing associate', 'Salary': 34208.0, 'Bonus': 6620.0, 'ID_employee': 7009.0}
# {'JobTitle': 'data scientist', 'Salary': 82345.0, 'Bonus': 7211.0, 'ID_employee': 7010.0}
# {'JobTitle': 'marketing associate', 'Salary': 49303.0, 'Bonus': 6615.0, 'ID_employee': 7011.0}
# {'JobTitle': 'it', 'Salary': 98456.0, 'Bonus': 7177.0, 'ID_employee': 7012.0}
# {'JobTitle': 'manager', 'Salary': 129885.0, 'Bonus': 7314.0, 'ID_employee': 7013.0}
# {'JobTitle': 'financial analyst', 'Salary': 97797.0, 'Bonus': 5239.0, 'ID_employee': 7014.0}
# {'JobTitle': 'sales associate', 'Salary': 91566.0, 'Bonus': 6996.0, 'ID_employee': 7015.0}
# {'JobTitle': 'sales associate', 'Salary': 131608.0, 'Bonus': 6537.0, 'ID_employee': 7016.0}
# {'JobTitle': 'financial analyst', 'Salary': 65750.0, 'Bonus': 6177.0, 'ID_employee': 7017.0}
# {'JobTitle': 'marketing associate', 'Salary': 76806.0, 'Bonus': 6662.0, 'ID_employee': 7018.0}
# {'JobTitle': 'warehouse associate', 'Salary': 114733.0, 'Bonus': 6290.0, 'ID_employee': 7019.0}
# {'JobTitle': 'driver', 'Salary': 89170.0, 'Bonus': 6722.0, 'ID_employee': 7020.0}
# {'JobTitle': 'driver', 'Salary': 78751.0, 'Bonus': 6258.0, 'ID_employee': 7021.0}
# {'JobTitle': 'it', 'Salary': 75518.0, 'Bonus': 6711.0, 'ID_employee': 7022.0}
# {'JobTitle': 'marketing associate', 'Salary': 75294.0, 'Bonus': 6496.0, 'ID_employee': 7023.0}
# {'JobTitle': 'graphic designer', 'Salary': 127608.0, 'Bonus': 6558.0, 'ID_employee': 7024.0}
# {'JobTitle': 'financial analyst', 'Salary': 116069.0, 'Bonus': 6432.0, 'ID_employee': 7025.0}
# {'JobTitle': 'driver', 'Salary': 86122.0, 'Bonus': 6295.0, 'ID_employee': 7026.0}
# {'JobTitle': 'warehouse associate', 'Salary': 68300.0, 'Bonus': 5953.0, 'ID_employee': 7027.0}
# {'JobTitle': 'financial analyst', 'Salary': 94590.0, 'Bonus': 5327.0, 'ID_employee': 7028.0}
# {'JobTitle': 'sales associate', 'Salary': 87418.0, 'Bonus': 6430.0, 'ID_employee': 7029.0}
# {'JobTitle': 'graphic designer', 'Salary': 104082.0, 'Bonus': 5477.0, 'ID_employee': 7030.0}
# {'JobTitle': 'it', 'Salary': 94354.0, 'Bonus': 7052.0, 'ID_employee': 7031.0}
# {'JobTitle': 'data scientist', 'Salary': 90713.0, 'Bonus': 6552.0, 'ID_employee': 7032.0}
# {'JobTitle': 'manager', 'Salary': 113009.0, 'Bonus': 6812.0, 'ID_employee': 7033.0}
# {'JobTitle': 'marketing associate', 'Salary': 72030.0, 'Bonus': 5569.0, 'ID_employee': 7034.0}
# {'JobTitle': 'driver', 'Salary': 66203.0, 'Bonus': 5627.0, 'ID_employee': 7035.0}
# {'JobTitle': 'driver', 'Salary': 67210.0, 'Bonus': 5662.0, 'ID_employee': 7036.0}
# {'JobTitle': 'manager', 'Salary': 115383.0, 'Bonus': 5878.0, 'ID_employee': 7037.0}
# {'JobTitle': 'graphic designer', 'Salary': 120697.0, 'Bonus': 7205.0, 'ID_employee': 7038.0}
# {'JobTitle': 'data scientist', 'Salary': 125770.0, 'Bonus': 7301.0, 'ID_employee': 7039.0}
# {'JobTitle': 'data scientist', 'Salary': 97846.0, 'Bonus': 7198.0, 'ID_employee': 7040.0}
# {'JobTitle': 'sales associate', 'Salary': 76522.0, 'Bonus': 6900.0, 'ID_employee': 7041.0}
# {'JobTitle': 'sales associate', 'Salary': 87131.0, 'Bonus': 6356.0, 'ID_employee': 7042.0}
# {'JobTitle': 'it', 'Salary': 56656.0, 'Bonus': 5914.0, 'ID_employee': 7043.0}
# {'JobTitle': 'it', 'Salary': 70157.0, 'Bonus': 6016.0, 'ID_employee': 7044.0}
# {'JobTitle': 'data scientist', 'Salary': 98366.0, 'Bonus': 6398.0, 'ID_employee': 7045.0}
# {'JobTitle': 'data scientist', 'Salary': 73798.0, 'Bonus': 6224.0, 'ID_employee': 7046.0}
# {'JobTitle': 'marketing associate', 'Salary': 94763.0, 'Bonus': 5668.0, 'ID_employee': 7047.0}
# {'JobTitle': 'financial analyst', 'Salary': 101534.0, 'Bonus': 6861.0, 'ID_employee': 7048.0}
# {'JobTitle': 'sales associate', 'Salary': 90426.0, 'Bonus': 5020.0, 'ID_employee': 7049.0}
# {'JobTitle': 'it', 'Salary': 99369.0, 'Bonus': 6746.0, 'ID_employee': 7050.0}
# {'JobTitle': 'graphic designer', 'Salary': 55845.0, 'Bonus': 6616.0, 'ID_employee': 7051.0}
# {'JobTitle': 'financial analyst', 'Salary': 48570.0, 'Bonus': 6604.0, 'ID_employee': 7052.0}
# {'JobTitle': 'data scientist', 'Salary': 113274.0, 'Bonus': 6186.0, 'ID_employee': 7053.0}
# {'JobTitle': 'marketing associate', 'Salary': 86241.0, 'Bonus': 5814.0, 'ID_employee': 7054.0}
# {'JobTitle': 'driver', 'Salary': 100433.0, 'Bonus': 5090.0, 'ID_employee': 7055.0}
# {'JobTitle': 'marketing associate', 'Salary': 123242.0, 'Bonus': 5453.0, 'ID_employee': 7056.0}
# {'JobTitle': 'sales associate', 'Salary': 87585.0, 'Bonus': 6476.0, 'ID_employee': 7057.0}
# {'JobTitle': 'it', 'Salary': 45747.0, 'Bonus': 4890.0, 'ID_employee': 7058.0}
# {'JobTitle': 'marketing associate', 'Salary': 36972.0, 'Bonus': 7058.0, 'ID_employee': 7059.0}
# {'JobTitle': 'sales associate', 'Salary': 64754.0, 'Bonus': 7377.0, 'ID_employee': 7060.0}
# {'JobTitle': 'it', 'Salary': 132267.0, 'Bonus': 5679.0, 'ID_employee': 7061.0}
# {'JobTitle': 'marketing associate', 'Salary': 112507.0, 'Bonus': 7460.0, 'ID_employee': 7062.0}
# {'JobTitle': 'marketing associate', 'Salary': 100316.0, 'Bonus': 6010.0, 'ID_employee': 7063.0}
# {'JobTitle': 'it', 'Salary': 111120.0, 'Bonus': 6536.0, 'ID_employee': 7064.0}
# {'JobTitle': 'data scientist', 'Salary': 76523.0, 'Bonus': 7122.0, 'ID_employee': 7065.0}
# {'JobTitle': 'driver', 'Salary': 91160.0, 'Bonus': 5863.0, 'ID_employee': 7066.0}
# {'JobTitle': 'financial analyst', 'Salary': 66935.0, 'Bonus': 6508.0, 'ID_employee': 7067.0}
# {'JobTitle': 'data scientist', 'Salary': 138365.0, 'Bonus': 5359.0, 'ID_employee': 7068.0}
# {'JobTitle': 'marketing associate', 'Salary': 59006.0, 'Bonus': 5876.0, 'ID_employee': 7069.0}
# {'JobTitle': 'marketing associate', 'Salary': 74305.0, 'Bonus': 7126.0, 'ID_employee': 7070.0}
# {'JobTitle': 'marketing associate', 'Salary': 38451.0, 'Bonus': 5562.0, 'ID_employee': 7071.0}
# {'JobTitle': 'graphic designer', 'Salary': 113465.0, 'Bonus': 3846.0, 'ID_employee': 7072.0}
# {'JobTitle': 'sales associate', 'Salary': 66377.0, 'Bonus': 5803.0, 'ID_employee': 7073.0}
# {'JobTitle': 'graphic designer', 'Salary': 55569.0, 'Bonus': 5236.0, 'ID_employee': 7074.0}
# {'JobTitle': 'manager', 'Salary': 119033.0, 'Bonus': 6381.0, 'ID_employee': 7075.0}
# {'JobTitle': 'marketing associate', 'Salary': 106315.0, 'Bonus': 5618.0, 'ID_employee': 7076.0}
# {'JobTitle': 'it', 'Salary': 105598.0, 'Bonus': 5380.0, 'ID_employee': 7077.0}
# {'JobTitle': 'financial analyst', 'Salary': 78084.0, 'Bonus': 5598.0, 'ID_employee': 7078.0}
# {'JobTitle': 'graphic designer', 'Salary': 41603.0, 'Bonus': 6092.0, 'ID_employee': 7079.0}
# {'JobTitle': 'driver', 'Salary': 78002.0, 'Bonus': 5175.0, 'ID_employee': 7080.0}
# {'JobTitle': 'sales associate', 'Salary': 81866.0, 'Bonus': 5183.0, 'ID_employee': 7081.0}
# {'JobTitle': 'data scientist', 'Salary': 91711.0, 'Bonus': 6775.0, 'ID_employee': 7082.0}
# {'JobTitle': 'marketing associate', 'Salary': 93805.0, 'Bonus': 6044.0, 'ID_employee': 7083.0}
# {'JobTitle': 'marketing associate', 'Salary': 109931.0, 'Bonus': 5878.0, 'ID_employee': 7084.0}
# {'JobTitle': 'marketing associate', 'Salary': 88365.0, 'Bonus': 4668.0, 'ID_employee': 7085.0}
# {'JobTitle': 'warehouse associate', 'Salary': 79334.0, 'Bonus': 6505.0, 'ID_employee': 7086.0}
# {'JobTitle': 'financial analyst', 'Salary': 98512.0, 'Bonus': 4548.0, 'ID_employee': 7087.0}
# {'JobTitle': 'data scientist', 'Salary': 78910.0, 'Bonus': 5927.0, 'ID_employee': 7088.0}
# {'JobTitle': 'warehouse associate', 'Salary': 125574.0, 'Bonus': 5688.0, 'ID_employee': 7089.0}
# {'JobTitle': 'warehouse associate', 'Salary': 106963.0, 'Bonus': 5084.0, 'ID_employee': 7090.0}
# {'JobTitle': 'it', 'Salary': 111770.0, 'Bonus': 5345.0, 'ID_employee': 7091.0}
# {'JobTitle': 'marketing associate', 'Salary': 57672.0, 'Bonus': 6476.0, 'ID_employee': 7092.0}
# {'JobTitle': 'graphic designer', 'Salary': 97768.0, 'Bonus': 7233.0, 'ID_employee': 7093.0}
# {'JobTitle': 'graphic designer', 'Salary': 76103.0, 'Bonus': 5173.0, 'ID_employee': 7094.0}
# {'JobTitle': 'warehouse associate', 'Salary': 93441.0, 'Bonus': 5499.0, 'ID_employee': 7095.0}
# {'JobTitle': 'data scientist', 'Salary': 108366.0, 'Bonus': 5108.0, 'ID_employee': 7096.0}
# {'JobTitle': 'warehouse associate', 'Salary': 85453.0, 'Bonus': 5135.0, 'ID_employee': 7097.0}
# {'JobTitle': 'data scientist', 'Salary': 79765.0, 'Bonus': 5329.0, 'ID_employee': 7098.0}
# {'JobTitle': 'financial analyst', 'Salary': 129683.0, 'Bonus': 5754.0, 'ID_employee': 7099.0}
# {'JobTitle': 'financial analyst', 'Salary': 76908.0, 'Bonus': 4756.0, 'ID_employee': 7100.0}
# {'JobTitle': 'financial analyst', 'Salary': 93696.0, 'Bonus': 5029.0, 'ID_employee': 7101.0}
# {'JobTitle': 'sales associate', 'Salary': 83095.0, 'Bonus': 5284.0, 'ID_employee': 7102.0}
# {'JobTitle': 'it', 'Salary': 81325.0, 'Bonus': 5647.0, 'ID_employee': 7103.0}
# {'JobTitle': 'warehouse associate', 'Salary': 102106.0, 'Bonus': 5195.0, 'ID_employee': 7104.0}
# {'JobTitle': 'graphic designer', 'Salary': 80635.0, 'Bonus': 4322.0, 'ID_employee': 7105.0}
# {'JobTitle': 'marketing associate', 'Salary': 73404.0, 'Bonus': 5038.0, 'ID_employee': 7106.0}
# {'JobTitle': 'graphic designer', 'Salary': 133741.0, 'Bonus': 4925.0, 'ID_employee': 7107.0}
# {'JobTitle': 'manager', 'Salary': 104329.0, 'Bonus': 4962.0, 'ID_employee': 7108.0}
# {'JobTitle': 'sales associate', 'Salary': 102745.0, 'Bonus': 6303.0, 'ID_employee': 7109.0}
# {'JobTitle': 'manager', 'Salary': 146008.0, 'Bonus': 6235.0, 'ID_employee': 7110.0}
# {'JobTitle': 'marketing associate', 'Salary': 68364.0, 'Bonus': 4076.0, 'ID_employee': 7111.0}
# {'JobTitle': 'data scientist', 'Salary': 96584.0, 'Bonus': 5293.0, 'ID_employee': 7112.0}
# {'JobTitle': 'data scientist', 'Salary': 102265.0, 'Bonus': 4760.0, 'ID_employee': 7113.0}
# {'JobTitle': 'marketing associate', 'Salary': 81249.0, 'Bonus': 4845.0, 'ID_employee': 7114.0}
# {'JobTitle': 'it', 'Salary': 101791.0, 'Bonus': 6083.0, 'ID_employee': 7115.0}
# {'JobTitle': 'marketing associate', 'Salary': 77584.0, 'Bonus': 4524.0, 'ID_employee': 7116.0}
# {'JobTitle': 'driver', 'Salary': 88175.0, 'Bonus': 5004.0, 'ID_employee': 7117.0}
# {'JobTitle': 'data scientist', 'Salary': 65816.0, 'Bonus': 6817.0, 'ID_employee': 7118.0}
# {'JobTitle': 'marketing associate', 'Salary': 73685.0, 'Bonus': 4439.0, 'ID_employee': 7119.0}
# {'JobTitle': 'it', 'Salary': 55560.0, 'Bonus': 4449.0, 'ID_employee': 7120.0}
# {'JobTitle': 'data scientist', 'Salary': 106452.0, 'Bonus': 5346.0, 'ID_employee': 7121.0}
# {'JobTitle': 'warehouse associate', 'Salary': 87575.0, 'Bonus': 4422.0, 'ID_employee': 7122.0}
# {'JobTitle': 'driver', 'Salary': 113140.0, 'Bonus': 4079.0, 'ID_employee': 7123.0}
# {'JobTitle': 'data scientist', 'Salary': 100505.0, 'Bonus': 4626.0, 'ID_employee': 7124.0}
# {'JobTitle': 'it', 'Salary': 104589.0, 'Bonus': 4536.0, 'ID_employee': 7125.0}
# {'JobTitle': 'it', 'Salary': 61081.0, 'Bonus': 6337.0, 'ID_employee': 7126.0}
# {'JobTitle': 'marketing associate', 'Salary': 79237.0, 'Bonus': 4453.0, 'ID_employee': 7127.0}
# {'JobTitle': 'driver', 'Salary': 108475.0, 'Bonus': 4489.0, 'ID_employee': 7128.0}
# {'JobTitle': 'graphic designer', 'Salary': 99942.0, 'Bonus': 5352.0, 'ID_employee': 7129.0}
# {'JobTitle': 'data scientist', 'Salary': 108296.0, 'Bonus': 4708.0, 'ID_employee': 7130.0}
# {'JobTitle': 'it', 'Salary': 126370.0, 'Bonus': 6032.0, 'ID_employee': 7131.0}
# {'JobTitle': 'financial analyst', 'Salary': 122142.0, 'Bonus': 5435.0, 'ID_employee': 7132.0}
# {'JobTitle': 'driver', 'Salary': 75919.0, 'Bonus': 5613.0, 'ID_employee': 7133.0}
# {'JobTitle': 'it', 'Salary': 103416.0, 'Bonus': 5536.0, 'ID_employee': 7134.0}
# {'JobTitle': 'driver', 'Salary': 104468.0, 'Bonus': 4466.0, 'ID_employee': 7135.0}
# {'JobTitle': 'sales associate', 'Salary': 117202.0, 'Bonus': 5068.0, 'ID_employee': 7136.0}
# {'JobTitle': 'data scientist', 'Salary': 139141.0, 'Bonus': 4969.0, 'ID_employee': 7137.0}
# {'JobTitle': 'warehouse associate', 'Salary': 134109.0, 'Bonus': 4184.0, 'ID_employee': 7138.0}
# {'JobTitle': 'sales associate', 'Salary': 66887.0, 'Bonus': 5014.0, 'ID_employee': 7139.0}
# {'JobTitle': 'it', 'Salary': 124847.0, 'Bonus': 3100.0, 'ID_employee': 7140.0}
# {'JobTitle': 'financial analyst', 'Salary': 50758.0, 'Bonus': 5386.0, 'ID_employee': 7141.0}
# {'JobTitle': 'graphic designer', 'Salary': 75316.0, 'Bonus': 5861.0, 'ID_employee': 7142.0}
# {'JobTitle': 'graphic designer', 'Salary': 111502.0, 'Bonus': 4413.0, 'ID_employee': 7143.0}
# {'JobTitle': 'sales associate', 'Salary': 116642.0, 'Bonus': 4621.0, 'ID_employee': 7144.0}
# {'JobTitle': 'it', 'Salary': 113283.0, 'Bonus': 5404.0, 'ID_employee': 7145.0}
# {'JobTitle': 'marketing associate', 'Salary': 86538.0, 'Bonus': 4212.0, 'ID_employee': 7146.0}
# {'JobTitle': 'marketing associate', 'Salary': 77742.0, 'Bonus': 5430.0, 'ID_employee': 7147.0}
# {'JobTitle': 'financial analyst', 'Salary': 114171.0, 'Bonus': 3768.0, 'ID_employee': 7148.0}
# {'JobTitle': 'graphic designer', 'Salary': 106204.0, 'Bonus': 4534.0, 'ID_employee': 7149.0}
# {'JobTitle': 'graphic designer', 'Salary': 111041.0, 'Bonus': 3727.0, 'ID_employee': 7150.0}
# {'JobTitle': 'financial analyst', 'Salary': 95795.0, 'Bonus': 5723.0, 'ID_employee': 7151.0}
# {'JobTitle': 'marketing associate', 'Salary': 98575.0, 'Bonus': 5410.0, 'ID_employee': 7152.0}
# {'JobTitle': 'software engineer', 'Salary': 117131.0, 'Bonus': 2324.0, 'ID_employee': 7153.0}
# {'JobTitle': 'marketing associate', 'Salary': 38613.0, 'Bonus': 6079.0, 'ID_employee': 7154.0}
# {'JobTitle': 'marketing associate', 'Salary': 62866.0, 'Bonus': 5114.0, 'ID_employee': 7155.0}
# {'JobTitle': 'graphic designer', 'Salary': 108731.0, 'Bonus': 4793.0, 'ID_employee': 7156.0}
# {'JobTitle': 'marketing associate', 'Salary': 47739.0, 'Bonus': 4829.0, 'ID_employee': 7157.0}
# {'JobTitle': 'sales associate', 'Salary': 64920.0, 'Bonus': 4967.0, 'ID_employee': 7158.0}
# {'JobTitle': 'software engineer', 'Salary': 79177.0, 'Bonus': 3661.0, 'ID_employee': 7159.0}
# {'JobTitle': 'manager', 'Salary': 136215.0, 'Bonus': 3603.0, 'ID_employee': 7160.0}
# {'JobTitle': 'marketing associate', 'Salary': 63327.0, 'Bonus': 4066.0, 'ID_employee': 7161.0}
# {'JobTitle': 'marketing associate', 'Salary': 52578.0, 'Bonus': 5538.0, 'ID_employee': 7162.0}
# {'JobTitle': 'driver', 'Salary': 114436.0, 'Bonus': 4249.0, 'ID_employee': 7163.0}
# {'JobTitle': 'marketing associate', 'Salary': 99543.0, 'Bonus': 4442.0, 'ID_employee': 7164.0}
# {'JobTitle': 'sales associate', 'Salary': 60983.0, 'Bonus': 5022.0, 'ID_employee': 7165.0}
# {'JobTitle': 'marketing associate', 'Salary': 55885.0, 'Bonus': 3795.0, 'ID_employee': 7166.0}
# {'JobTitle': 'driver', 'Salary': 107064.0, 'Bonus': 4202.0, 'ID_employee': 7167.0}
# {'JobTitle': 'marketing associate', 'Salary': 107370.0, 'Bonus': 4916.0, 'ID_employee': 7168.0}
# {'JobTitle': 'marketing associate', 'Salary': 39741.0, 'Bonus': 4981.0, 'ID_employee': 7169.0}
# {'JobTitle': 'driver', 'Salary': 103242.0, 'Bonus': 4495.0, 'ID_employee': 7170.0}
# {'JobTitle': 'driver', 'Salary': 120112.0, 'Bonus': 5070.0, 'ID_employee': 7171.0}
# {'JobTitle': 'sales associate', 'Salary': 83308.0, 'Bonus': 3653.0, 'ID_employee': 7172.0}
# {'JobTitle': 'marketing associate', 'Salary': 36585.0, 'Bonus': 4373.0, 'ID_employee': 7173.0}
# {'JobTitle': 'graphic designer', 'Salary': 115344.0, 'Bonus': 4827.0, 'ID_employee': 7174.0}
# {'JobTitle': 'it', 'Salary': 96982.0, 'Bonus': 4750.0, 'ID_employee': 7175.0}
# {'JobTitle': 'financial analyst', 'Salary': 80030.0, 'Bonus': 5481.0, 'ID_employee': 7176.0}
# {'JobTitle': 'financial analyst', 'Salary': 84047.0, 'Bonus': 4683.0, 'ID_employee': 7177.0}
# {'JobTitle': 'data scientist', 'Salary': 84764.0, 'Bonus': 4409.0, 'ID_employee': 7178.0}
# {'JobTitle': 'warehouse associate', 'Salary': 120277.0, 'Bonus': 4617.0, 'ID_employee': 7179.0}
# {'JobTitle': 'marketing associate', 'Salary': 81661.0, 'Bonus': 4965.0, 'ID_employee': 7180.0}
# {'JobTitle': 'manager', 'Salary': 149893.0, 'Bonus': 5120.0, 'ID_employee': 7181.0}
# {'JobTitle': 'sales associate', 'Salary': 130417.0, 'Bonus': 4694.0, 'ID_employee': 7182.0}
# {'JobTitle': 'marketing associate', 'Salary': 38855.0, 'Bonus': 4503.0, 'ID_employee': 7183.0}
# {'JobTitle': 'graphic designer', 'Salary': 96232.0, 'Bonus': 3697.0, 'ID_employee': 7184.0}
# {'JobTitle': 'marketing associate', 'Salary': 86563.0, 'Bonus': 4415.0, 'ID_employee': 7185.0}
# {'JobTitle': 'graphic designer', 'Salary': 72248.0, 'Bonus': 3634.0, 'ID_employee': 7186.0}
# {'JobTitle': 'data scientist', 'Salary': 125828.0, 'Bonus': 3961.0, 'ID_employee': 7187.0}
# {'JobTitle': 'graphic designer', 'Salary': 75017.0, 'Bonus': 5576.0, 'ID_employee': 7188.0}
# {'JobTitle': 'marketing associate', 'Salary': 100415.0, 'Bonus': 3871.0, 'ID_employee': 7189.0}
# {'JobTitle': 'manager', 'Salary': 145095.0, 'Bonus': 3889.0, 'ID_employee': 7190.0}
# {'JobTitle': 'data scientist', 'Salary': 115641.0, 'Bonus': 4339.0, 'ID_employee': 7191.0}
# {'JobTitle': 'financial analyst', 'Salary': 119058.0, 'Bonus': 4037.0, 'ID_employee': 7192.0}
# {'JobTitle': 'warehouse associate', 'Salary': 106722.0, 'Bonus': 4044.0, 'ID_employee': 7193.0}
# {'JobTitle': 'financial analyst', 'Salary': 91129.0, 'Bonus': 4825.0, 'ID_employee': 7194.0}
# {'JobTitle': 'financial analyst', 'Salary': 92891.0, 'Bonus': 3578.0, 'ID_employee': 7195.0}
# {'JobTitle': 'data scientist', 'Salary': 141005.0, 'Bonus': 3384.0, 'ID_employee': 7196.0}
# {'JobTitle': 'it', 'Salary': 131411.0, 'Bonus': 3084.0, 'ID_employee': 7197.0}
# {'JobTitle': 'sales associate', 'Salary': 96900.0, 'Bonus': 4157.0, 'ID_employee': 7198.0}
# {'JobTitle': 'marketing associate', 'Salary': 88820.0, 'Bonus': 4289.0, 'ID_employee': 7199.0}
# {'JobTitle': 'marketing associate', 'Salary': 112489.0, 'Bonus': 4237.0, 'ID_employee': 7200.0}
# {'JobTitle': 'marketing associate', 'Salary': 53839.0, 'Bonus': 3270.0, 'ID_employee': 7201.0}
# {'JobTitle': 'it', 'Salary': 64807.0, 'Bonus': 3887.0, 'ID_employee': 7202.0}
# {'JobTitle': 'it', 'Salary': 41151.0, 'Bonus': 4296.0, 'ID_employee': 7203.0}
# {'JobTitle': 'financial analyst', 'Salary': 114031.0, 'Bonus': 4510.0, 'ID_employee': 7204.0}
# {'JobTitle': 'manager', 'Salary': 119893.0, 'Bonus': 3721.0, 'ID_employee': 7205.0}
# {'JobTitle': 'sales associate', 'Salary': 94154.0, 'Bonus': 3964.0, 'ID_employee': 7206.0}
# {'JobTitle': 'marketing associate', 'Salary': 114906.0, 'Bonus': 4766.0, 'ID_employee': 7207.0}
# {'JobTitle': 'driver', 'Salary': 115981.0, 'Bonus': 2661.0, 'ID_employee': 7208.0}
# {'JobTitle': 'marketing associate', 'Salary': 93018.0, 'Bonus': 2730.0, 'ID_employee': 7209.0}
# {'JobTitle': 'marketing associate', 'Salary': 69928.0, 'Bonus': 4811.0, 'ID_employee': 7210.0}
# {'JobTitle': 'software engineer', 'Salary': 104623.0, 'Bonus': 3791.0, 'ID_employee': 7211.0}
# {'JobTitle': 'graphic designer', 'Salary': 63914.0, 'Bonus': 3521.0, 'ID_employee': 7212.0}
# {'JobTitle': 'graphic designer', 'Salary': 90474.0, 'Bonus': 3530.0, 'ID_employee': 7213.0}
# {'JobTitle': 'driver', 'Salary': 60026.0, 'Bonus': 4605.0, 'ID_employee': 7214.0}
# {'JobTitle': 'marketing associate', 'Salary': 108587.0, 'Bonus': 4275.0, 'ID_employee': 7215.0}
# {'JobTitle': 'financial analyst', 'Salary': 139042.0, 'Bonus': 2982.0, 'ID_employee': 7216.0}
# {'JobTitle': 'sales associate', 'Salary': 101423.0, 'Bonus': 3641.0, 'ID_employee': 7217.0}
# {'JobTitle': 'marketing associate', 'Salary': 95995.0, 'Bonus': 4045.0, 'ID_employee': 7218.0}
# {'JobTitle': 'it', 'Salary': 99472.0, 'Bonus': 3943.0, 'ID_employee': 7219.0}
# {'JobTitle': 'manager', 'Salary': 135638.0, 'Bonus': 2824.0, 'ID_employee': 7220.0}
# {'JobTitle': 'data scientist', 'Salary': 121457.0, 'Bonus': 4723.0, 'ID_employee': 7221.0}
# {'JobTitle': 'data scientist', 'Salary': 114141.0, 'Bonus': 3746.0, 'ID_employee': 7222.0}
# {'JobTitle': 'marketing associate', 'Salary': 107572.0, 'Bonus': 3107.0, 'ID_employee': 7223.0}
# {'JobTitle': 'sales associate', 'Salary': 142505.0, 'Bonus': 4214.0, 'ID_employee': 7224.0}
# {'JobTitle': 'sales associate', 'Salary': 106279.0, 'Bonus': 3892.0, 'ID_employee': 7225.0}
# {'JobTitle': 'manager', 'Salary': 106916.0, 'Bonus': 3959.0, 'ID_employee': 7226.0}
# {'JobTitle': 'it', 'Salary': 92257.0, 'Bonus': 3908.0, 'ID_employee': 7227.0}
# {'JobTitle': 'it', 'Salary': 59377.0, 'Bonus': 5236.0, 'ID_employee': 7228.0}
# {'JobTitle': 'marketing associate', 'Salary': 76726.0, 'Bonus': 4204.0, 'ID_employee': 7229.0}
# {'JobTitle': 'it', 'Salary': 112502.0, 'Bonus': 3988.0, 'ID_employee': 7230.0}
# {'JobTitle': 'financial analyst', 'Salary': 101515.0, 'Bonus': 2251.0, 'ID_employee': 7231.0}
# {'JobTitle': 'financial analyst', 'Salary': 67089.0, 'Bonus': 3078.0, 'ID_employee': 7232.0}
# {'JobTitle': 'driver', 'Salary': 97789.0, 'Bonus': 3536.0, 'ID_employee': 7233.0}
# {'JobTitle': 'marketing associate', 'Salary': 54945.0, 'Bonus': 2991.0, 'ID_employee': 7234.0}
# {'JobTitle': 'data scientist', 'Salary': 121239.0, 'Bonus': 3078.0, 'ID_employee': 7235.0}
# {'JobTitle': 'data scientist', 'Salary': 87314.0, 'Bonus': 3688.0, 'ID_employee': 7236.0}
# {'JobTitle': 'driver', 'Salary': 124530.0, 'Bonus': 3647.0, 'ID_employee': 7237.0}
# {'JobTitle': 'driver', 'Salary': 67150.0, 'Bonus': 3255.0, 'ID_employee': 7238.0}
# {'JobTitle': 'financial analyst', 'Salary': 63300.0, 'Bonus': 3655.0, 'ID_employee': 7239.0}
# {'JobTitle': 'marketing associate', 'Salary': 60271.0, 'Bonus': 3927.0, 'ID_employee': 7240.0}
# {'JobTitle': 'marketing associate', 'Salary': 66028.0, 'Bonus': 3745.0, 'ID_employee': 7241.0}
# {'JobTitle': 'marketing associate', 'Salary': 91300.0, 'Bonus': 3680.0, 'ID_employee': 7242.0}
# {'JobTitle': 'financial analyst', 'Salary': 90999.0, 'Bonus': 2963.0, 'ID_employee': 7243.0}
# {'JobTitle': 'sales associate', 'Salary': 86795.0, 'Bonus': 3453.0, 'ID_employee': 7244.0}
# {'JobTitle': 'it', 'Salary': 110627.0, 'Bonus': 2041.0, 'ID_employee': 7245.0}
# {'JobTitle': 'marketing associate', 'Salary': 97696.0, 'Bonus': 3888.0, 'ID_employee': 7246.0}
# {'JobTitle': 'marketing associate', 'Salary': 62738.0, 'Bonus': 2656.0, 'ID_employee': 7247.0}
# {'JobTitle': 'it', 'Salary': 112169.0, 'Bonus': 2763.0, 'ID_employee': 7248.0}
# {'JobTitle': 'marketing associate', 'Salary': 98796.0, 'Bonus': 3042.0, 'ID_employee': 7249.0}
# {'JobTitle': 'financial analyst', 'Salary': 96665.0, 'Bonus': 2645.0, 'ID_employee': 7250.0}
# {'JobTitle': 'graphic designer', 'Salary': 91030.0, 'Bonus': 3318.0, 'ID_employee': 7251.0}
# {'JobTitle': 'it', 'Salary': 106945.0, 'Bonus': 2041.0, 'ID_employee': 7252.0}
# {'JobTitle': 'graphic designer', 'Salary': 81545.0, 'Bonus': 3418.0, 'ID_employee': 7253.0}
# {'JobTitle': 'marketing associate', 'Salary': 80789.0, 'Bonus': 1884.0, 'ID_employee': 7254.0}
# {'JobTitle': 'marketing associate', 'Salary': 85253.0, 'Bonus': 2777.0, 'ID_employee': 7255.0}
# {'JobTitle': 'marketing associate', 'Salary': 62644.0, 'Bonus': 3270.0, 'ID_employee': 7256.0}
# {'JobTitle': 'software engineer', 'Salary': 108476.0, 'Bonus': 11128.0, 'ID_employee': 7257.0}
# {'JobTitle': 'software engineer', 'Salary': 108080.0, 'Bonus': 10154.0, 'ID_employee': 7258.0}
# {'JobTitle': 'graphic designer', 'Salary': 99464.0, 'Bonus': 9319.0, 'ID_employee': 7259.0}
# {'JobTitle': 'software engineer', 'Salary': 97523.0, 'Bonus': 10240.0, 'ID_employee': 7260.0}
# {'JobTitle': 'graphic designer', 'Salary': 102261.0, 'Bonus': 10212.0, 'ID_employee': 7261.0}
# {'JobTitle': 'sales associate', 'Salary': 90386.0, 'Bonus': 9461.0, 'ID_employee': 7262.0}
# {'JobTitle': 'warehouse associate', 'Salary': 108446.0, 'Bonus': 9210.0, 'ID_employee': 7263.0}
# {'JobTitle': 'financial analyst', 'Salary': 83323.0, 'Bonus': 9329.0, 'ID_employee': 7264.0}
# {'JobTitle': 'warehouse associate', 'Salary': 85205.0, 'Bonus': 9792.0, 'ID_employee': 7265.0}
# {'JobTitle': 'software engineer', 'Salary': 132823.0, 'Bonus': 9625.0, 'ID_employee': 7266.0}
# {'JobTitle': 'software engineer', 'Salary': 100305.0, 'Bonus': 9618.0, 'ID_employee': 7267.0}
# {'JobTitle': 'graphic designer', 'Salary': 88566.0, 'Bonus': 9469.0, 'ID_employee': 7268.0}
# {'JobTitle': 'warehouse associate', 'Salary': 104271.0, 'Bonus': 10177.0, 'ID_employee': 7269.0}
# {'JobTitle': 'software engineer', 'Salary': 66359.0, 'Bonus': 10137.0, 'ID_employee': 7270.0}
# {'JobTitle': 'sales associate', 'Salary': 103007.0, 'Bonus': 10512.0, 'ID_employee': 7271.0}
# {'JobTitle': 'software engineer', 'Salary': 96040.0, 'Bonus': 10050.0, 'ID_employee': 7272.0}
# {'JobTitle': 'software engineer', 'Salary': 91674.0, 'Bonus': 9780.0, 'ID_employee': 7273.0}
# {'JobTitle': 'software engineer', 'Salary': 92928.0, 'Bonus': 9094.0, 'ID_employee': 7274.0}
# {'JobTitle': 'it', 'Salary': 78986.0, 'Bonus': 9023.0, 'ID_employee': 7275.0}
# {'JobTitle': 'data scientist', 'Salary': 96355.0, 'Bonus': 9784.0, 'ID_employee': 7276.0}
# {'JobTitle': 'data scientist', 'Salary': 87121.0, 'Bonus': 8703.0, 'ID_employee': 7277.0}
# {'JobTitle': 'software engineer', 'Salary': 88724.0, 'Bonus': 8949.0, 'ID_employee': 7278.0}
# {'JobTitle': 'warehouse associate', 'Salary': 58219.0, 'Bonus': 9868.0, 'ID_employee': 7279.0}
# {'JobTitle': 'software engineer', 'Salary': 119024.0, 'Bonus': 11293.0, 'ID_employee': 7280.0}
# {'JobTitle': 'software engineer', 'Salary': 81503.0, 'Bonus': 9729.0, 'ID_employee': 7281.0}
# {'JobTitle': 'marketing associate', 'Salary': 86886.0, 'Bonus': 9424.0, 'ID_employee': 7282.0}
# {'JobTitle': 'sales associate', 'Salary': 90780.0, 'Bonus': 9353.0, 'ID_employee': 7283.0}
# {'JobTitle': 'software engineer', 'Salary': 89474.0, 'Bonus': 9104.0, 'ID_employee': 7284.0}
# {'JobTitle': 'software engineer', 'Salary': 112466.0, 'Bonus': 9493.0, 'ID_employee': 7285.0}
# {'JobTitle': 'financial analyst', 'Salary': 97328.0, 'Bonus': 9874.0, 'ID_employee': 7286.0}
# {'JobTitle': 'graphic designer', 'Salary': 86766.0, 'Bonus': 9841.0, 'ID_employee': 7287.0}
# {'JobTitle': 'software engineer', 'Salary': 88814.0, 'Bonus': 10153.0, 'ID_employee': 7288.0}
# {'JobTitle': 'driver', 'Salary': 82832.0, 'Bonus': 9958.0, 'ID_employee': 7289.0}
# {'JobTitle': 'sales associate', 'Salary': 66168.0, 'Bonus': 9242.0, 'ID_employee': 7290.0}
# {'JobTitle': 'data scientist', 'Salary': 59212.0, 'Bonus': 10209.0, 'ID_employee': 7291.0}
# {'JobTitle': 'data scientist', 'Salary': 55189.0, 'Bonus': 9405.0, 'ID_employee': 7292.0}
# {'JobTitle': 'manager', 'Salary': 131311.0, 'Bonus': 11067.0, 'ID_employee': 7293.0}
# {'JobTitle': 'data scientist', 'Salary': 50401.0, 'Bonus': 8590.0, 'ID_employee': 7294.0}
# {'JobTitle': 'graphic designer', 'Salary': 83031.0, 'Bonus': 10240.0, 'ID_employee': 7295.0}
# {'JobTitle': 'financial analyst', 'Salary': 111019.0, 'Bonus': 10042.0, 'ID_employee': 7296.0}
# {'JobTitle': 'warehouse associate', 'Salary': 48755.0, 'Bonus': 9931.0, 'ID_employee': 7297.0}
# {'JobTitle': 'warehouse associate', 'Salary': 59044.0, 'Bonus': 9368.0, 'ID_employee': 7298.0}
# {'JobTitle': 'manager', 'Salary': 146615.0, 'Bonus': 10173.0, 'ID_employee': 7299.0}
# {'JobTitle': 'graphic designer', 'Salary': 69462.0, 'Bonus': 8872.0, 'ID_employee': 7300.0}
# {'JobTitle': 'manager', 'Salary': 119162.0, 'Bonus': 9395.0, 'ID_employee': 7301.0}
# {'JobTitle': 'software engineer', 'Salary': 68466.0, 'Bonus': 8384.0, 'ID_employee': 7302.0}
# {'JobTitle': 'warehouse associate', 'Salary': 109419.0, 'Bonus': 8375.0, 'ID_employee': 7303.0}
# {'JobTitle': 'software engineer', 'Salary': 80355.0, 'Bonus': 9945.0, 'ID_employee': 7304.0}
# {'JobTitle': 'software engineer', 'Salary': 82534.0, 'Bonus': 8914.0, 'ID_employee': 7305.0}
# {'JobTitle': 'it', 'Salary': 127769.0, 'Bonus': 8802.0, 'ID_employee': 7306.0}
# {'JobTitle': 'sales associate', 'Salary': 52290.0, 'Bonus': 9330.0, 'ID_employee': 7307.0}
# {'JobTitle': 'it', 'Salary': 47036.0, 'Bonus': 9130.0, 'ID_employee': 7308.0}
# {'JobTitle': 'warehouse associate', 'Salary': 76517.0, 'Bonus': 8502.0, 'ID_employee': 7309.0}
# {'JobTitle': 'driver', 'Salary': 90368.0, 'Bonus': 8215.0, 'ID_employee': 7310.0}
# {'JobTitle': 'financial analyst', 'Salary': 106194.0, 'Bonus': 9421.0, 'ID_employee': 7311.0}
# {'JobTitle': 'driver', 'Salary': 97414.0, 'Bonus': 8833.0, 'ID_employee': 7312.0}
# {'JobTitle': 'data scientist', 'Salary': 110731.0, 'Bonus': 8643.0, 'ID_employee': 7313.0}
# {'JobTitle': 'software engineer', 'Salary': 125572.0, 'Bonus': 8245.0, 'ID_employee': 7314.0}
# {'JobTitle': 'driver', 'Salary': 72754.0, 'Bonus': 8014.0, 'ID_employee': 7315.0}
# {'JobTitle': 'sales associate', 'Salary': 135013.0, 'Bonus': 8972.0, 'ID_employee': 7316.0}
# {'JobTitle': 'data scientist', 'Salary': 101173.0, 'Bonus': 9255.0, 'ID_employee': 7317.0}
# {'JobTitle': 'it', 'Salary': 126828.0, 'Bonus': 9310.0, 'ID_employee': 7318.0}
# ...
# {'JobTitle': 'financial analyst', 'Salary': 104744.0, 'Bonus': 6425.0, 'ID_employee': 7610.0}
# {'JobTitle': 'driver', 'Salary': 95795.0, 'Bonus': 4898.0, 'ID_employee': 7611.0}
# {'JobTitle': 'manager', 'Salary': 103156.0, 'Bonus': 6277.0, 'ID_employee': 7612.0}
# {'JobTitle': 'driver', 'Salary': 92760.0, 'Bonus': 4826.0, 'ID_employee': 7613.0}
# {'JobTitle': 'data scientist', 'Salary': 93742.0, 'Bonus': 6580.0, 'ID_employee': 7614.0}
# {'JobTitle': 'sales associate', 'Salary': 124470.0, 'Bonus': 5454.0, 'ID_employee': 7615.0}
# {'JobTitle': 'software engineer', 'Salary': 132323.0, 'Bonus': 4872.0, 'ID_employee': 7616.0}
# {'JobTitle': 'sales associate', 'Salary': 70595.0, 'Bonus': 5234.0, 'ID_employee': 7617.0}
# {'JobTitle': 'software engineer', 'Salary': 71278.0, 'Bonus': 4701.0, 'ID_employee': 7618.0}
# {'JobTitle': 'data scientist', 'Salary': 53855.0, 'Bonus': 4980.0, 'ID_employee': 7619.0}
# {'JobTitle': 'it', 'Salary': 98423.0, 'Bonus': 3879.0, 'ID_employee': 7620.0}
# {'JobTitle': 'software engineer', 'Salary': 126239.0, 'Bonus': 5396.0, 'ID_employee': 7621.0}
# {'JobTitle': 'sales associate', 'Salary': 101133.0, 'Bonus': 4700.0, 'ID_employee': 7622.0}
# {'JobTitle': 'warehouse associate', 'Salary': 92516.0, 'Bonus': 5866.0, 'ID_employee': 7623.0}
# {'JobTitle': 'data scientist', 'Salary': 93320.0, 'Bonus': 7236.0, 'ID_employee': 7624.0}
# {'JobTitle': 'it', 'Salary': 106584.0, 'Bonus': 5426.0, 'ID_employee': 7625.0}
# {'JobTitle': 'warehouse associate', 'Salary': 90612.0, 'Bonus': 5913.0, 'ID_employee': 7626.0}
# {'JobTitle': 'financial analyst', 'Salary': 82790.0, 'Bonus': 5826.0, 'ID_employee': 7627.0}
# {'JobTitle': 'financial analyst', 'Salary': 84628.0, 'Bonus': 5680.0, 'ID_employee': 7628.0}
# {'JobTitle': 'marketing associate', 'Salary': 110636.0, 'Bonus': 5239.0, 'ID_employee': 7629.0}
# {'JobTitle': 'manager', 'Salary': 135106.0, 'Bonus': 5066.0, 'ID_employee': 7630.0}
# {'JobTitle': 'graphic designer', 'Salary': 100160.0, 'Bonus': 5562.0, 'ID_employee': 7631.0}
# {'JobTitle': 'manager', 'Salary': 157169.0, 'Bonus': 5798.0, 'ID_employee': 7632.0}
# {'JobTitle': 'driver', 'Salary': 88230.0, 'Bonus': 5512.0, 'ID_employee': 7633.0}
# {'JobTitle': 'data scientist', 'Salary': 83674.0, 'Bonus': 4854.0, 'ID_employee': 7634.0}
# {'JobTitle': 'it', 'Salary': 118314.0, 'Bonus': 4892.0, 'ID_employee': 7635.0}
# {'JobTitle': 'software engineer', 'Salary': 119522.0, 'Bonus': 4650.0, 'ID_employee': 7636.0}
# {'JobTitle': 'sales associate', 'Salary': 84592.0, 'Bonus': 4635.0, 'ID_employee': 7637.0}
# {'JobTitle': 'sales associate', 'Salary': 121589.0, 'Bonus': 5133.0, 'ID_employee': 7638.0}
# {'JobTitle': 'warehouse associate', 'Salary': 71371.0, 'Bonus': 5220.0, 'ID_employee': 7639.0}
# {'JobTitle': 'data scientist', 'Salary': 96582.0, 'Bonus': 6350.0, 'ID_employee': 7640.0}
# {'JobTitle': 'data scientist', 'Salary': 108778.0, 'Bonus': 4357.0, 'ID_employee': 7641.0}
# {'JobTitle': 'driver', 'Salary': 128520.0, 'Bonus': 6151.0, 'ID_employee': 7642.0}
# {'JobTitle': 'driver', 'Salary': 62753.0, 'Bonus': 5735.0, 'ID_employee': 7643.0}
# {'JobTitle': 'software engineer', 'Salary': 128680.0, 'Bonus': 4677.0, 'ID_employee': 7644.0}
# {'JobTitle': 'manager', 'Salary': 152710.0, 'Bonus': 6107.0, 'ID_employee': 7645.0}
# {'JobTitle': 'software engineer', 'Salary': 109136.0, 'Bonus': 4572.0, 'ID_employee': 7646.0}
# {'JobTitle': 'it', 'Salary': 84878.0, 'Bonus': 5009.0, 'ID_employee': 7647.0}
# {'JobTitle': 'software engineer', 'Salary': 94745.0, 'Bonus': 5930.0, 'ID_employee': 7648.0}
# {'JobTitle': 'sales associate', 'Salary': 95505.0, 'Bonus': 4549.0, 'ID_employee': 7649.0}
# {'JobTitle': 'software engineer', 'Salary': 103181.0, 'Bonus': 4566.0, 'ID_employee': 7650.0}
# {'JobTitle': 'software engineer', 'Salary': 120096.0, 'Bonus': 4690.0, 'ID_employee': 7651.0}
# {'JobTitle': 'sales associate', 'Salary': 98499.0, 'Bonus': 6274.0, 'ID_employee': 7652.0}
# {'JobTitle': 'manager', 'Salary': 152081.0, 'Bonus': 4621.0, 'ID_employee': 7653.0}
# {'JobTitle': 'manager', 'Salary': 134450.0, 'Bonus': 5214.0, 'ID_employee': 7654.0}
# {'JobTitle': 'manager', 'Salary': 100819.0, 'Bonus': 5390.0, 'ID_employee': 7655.0}
# {'JobTitle': 'software engineer', 'Salary': 157277.0, 'Bonus': 4844.0, 'ID_employee': 7656.0}
# {'JobTitle': 'driver', 'Salary': 68175.0, 'Bonus': 5698.0, 'ID_employee': 7657.0}
# {'JobTitle': 'software engineer', 'Salary': 122624.0, 'Bonus': 4165.0, 'ID_employee': 7658.0}
# {'JobTitle': 'graphic designer', 'Salary': 101273.0, 'Bonus': 3817.0, 'ID_employee': 7659.0}
# {'JobTitle': 'sales associate', 'Salary': 59334.0, 'Bonus': 5729.0, 'ID_employee': 7660.0}
# {'JobTitle': 'manager', 'Salary': 152625.0, 'Bonus': 4702.0, 'ID_employee': 7661.0}
# {'JobTitle': 'data scientist', 'Salary': 90526.0, 'Bonus': 4191.0, 'ID_employee': 7662.0}
# {'JobTitle': 'manager', 'Salary': 133910.0, 'Bonus': 5795.0, 'ID_employee': 7663.0}
# {'JobTitle': 'data scientist', 'Salary': 77839.0, 'Bonus': 4458.0, 'ID_employee': 7664.0}
# {'JobTitle': 'driver', 'Salary': 61018.0, 'Bonus': 5513.0, 'ID_employee': 7665.0}
# {'JobTitle': 'driver', 'Salary': 118093.0, 'Bonus': 4115.0, 'ID_employee': 7666.0}
# {'JobTitle': 'software engineer', 'Salary': 106503.0, 'Bonus': 5225.0, 'ID_employee': 7667.0}
# {'JobTitle': 'financial analyst', 'Salary': 84683.0, 'Bonus': 4476.0, 'ID_employee': 7668.0}
# {'JobTitle': 'software engineer', 'Salary': 67913.0, 'Bonus': 4045.0, 'ID_employee': 7669.0}
# {'JobTitle': 'manager', 'Salary': 155826.0, 'Bonus': 4964.0, 'ID_employee': 7670.0}
# {'JobTitle': 'software engineer', 'Salary': 138184.0, 'Bonus': 4664.0, 'ID_employee': 7671.0}
# {'JobTitle': 'sales associate', 'Salary': 106798.0, 'Bonus': 5201.0, 'ID_employee': 7672.0}
# {'JobTitle': 'warehouse associate', 'Salary': 82343.0, 'Bonus': 5232.0, 'ID_employee': 7673.0}
# {'JobTitle': 'sales associate', 'Salary': 78625.0, 'Bonus': 4073.0, 'ID_employee': 7674.0}
# {'JobTitle': 'financial analyst', 'Salary': 99134.0, 'Bonus': 6255.0, 'ID_employee': 7675.0}
# {'JobTitle': 'graphic designer', 'Salary': 107818.0, 'Bonus': 5281.0, 'ID_employee': 7676.0}
# {'JobTitle': 'manager', 'Salary': 114621.0, 'Bonus': 3927.0, 'ID_employee': 7677.0}
# {'JobTitle': 'data scientist', 'Salary': 104290.0, 'Bonus': 3474.0, 'ID_employee': 7678.0}
# {'JobTitle': 'financial analyst', 'Salary': 111403.0, 'Bonus': 5078.0, 'ID_employee': 7679.0}
# {'JobTitle': 'it', 'Salary': 93802.0, 'Bonus': 5404.0, 'ID_employee': 7680.0}
# {'JobTitle': 'manager', 'Salary': 138163.0, 'Bonus': 3415.0, 'ID_employee': 7681.0}
# {'JobTitle': 'financial analyst', 'Salary': 115613.0, 'Bonus': 3881.0, 'ID_employee': 7682.0}
# {'JobTitle': 'warehouse associate', 'Salary': 64994.0, 'Bonus': 4310.0, 'ID_employee': 7683.0}
# {'JobTitle': 'driver', 'Salary': 100941.0, 'Bonus': 5992.0, 'ID_employee': 7684.0}
# {'JobTitle': 'manager', 'Salary': 163208.0, 'Bonus': 4095.0, 'ID_employee': 7685.0}
# {'JobTitle': 'sales associate', 'Salary': 51837.0, 'Bonus': 4472.0, 'ID_employee': 7686.0}
# {'JobTitle': 'graphic designer', 'Salary': 114048.0, 'Bonus': 5097.0, 'ID_employee': 7687.0}
# {'JobTitle': 'software engineer', 'Salary': 139068.0, 'Bonus': 4126.0, 'ID_employee': 7688.0}
# {'JobTitle': 'sales associate', 'Salary': 136209.0, 'Bonus': 3910.0, 'ID_employee': 7689.0}
# {'JobTitle': 'software engineer', 'Salary': 121910.0, 'Bonus': 4494.0, 'ID_employee': 7690.0}
# {'JobTitle': 'graphic designer', 'Salary': 82057.0, 'Bonus': 5268.0, 'ID_employee': 7691.0}
# {'JobTitle': 'sales associate', 'Salary': 96023.0, 'Bonus': 4148.0, 'ID_employee': 7692.0}
# {'JobTitle': 'software engineer', 'Salary': 82277.0, 'Bonus': 5460.0, 'ID_employee': 7693.0}
# {'JobTitle': 'graphic designer', 'Salary': 73142.0, 'Bonus': 4712.0, 'ID_employee': 7694.0}
# {'JobTitle': 'graphic designer', 'Salary': 107065.0, 'Bonus': 3652.0, 'ID_employee': 7695.0}
# {'JobTitle': 'sales associate', 'Salary': 120579.0, 'Bonus': 4687.0, 'ID_employee': 7696.0}
# {'JobTitle': 'sales associate', 'Salary': 49553.0, 'Bonus': 5784.0, 'ID_employee': 7697.0}
# {'JobTitle': 'driver', 'Salary': 110157.0, 'Bonus': 4275.0, 'ID_employee': 7698.0}
# {'JobTitle': 'marketing associate', 'Salary': 93054.0, 'Bonus': 4243.0, 'ID_employee': 7699.0}
# {'JobTitle': 'software engineer', 'Salary': 81515.0, 'Bonus': 5001.0, 'ID_employee': 7700.0}
# {'JobTitle': 'driver', 'Salary': 95898.0, 'Bonus': 4309.0, 'ID_employee': 7701.0}
# {'JobTitle': 'warehouse associate', 'Salary': 90000.0, 'Bonus': 4774.0, 'ID_employee': 7702.0}
# {'JobTitle': 'manager', 'Salary': 111896.0, 'Bonus': 5597.0, 'ID_employee': 7703.0}
# {'JobTitle': 'driver', 'Salary': 130082.0, 'Bonus': 4734.0, 'ID_employee': 7704.0}
# {'JobTitle': 'software engineer', 'Salary': 81057.0, 'Bonus': 5259.0, 'ID_employee': 7705.0}
# {'JobTitle': 'data scientist', 'Salary': 117215.0, 'Bonus': 4322.0, 'ID_employee': 7706.0}
# {'JobTitle': 'financial analyst', 'Salary': 141186.0, 'Bonus': 3415.0, 'ID_employee': 7707.0}
# {'JobTitle': 'manager', 'Salary': 114943.0, 'Bonus': 3438.0, 'ID_employee': 7708.0}
# {'JobTitle': 'data scientist', 'Salary': 107640.0, 'Bonus': 3896.0, 'ID_employee': 7709.0}
# {'JobTitle': 'manager', 'Salary': 80259.0, 'Bonus': 4791.0, 'ID_employee': 7710.0}
# {'JobTitle': 'data scientist', 'Salary': 61589.0, 'Bonus': 3990.0, 'ID_employee': 7711.0}
# {'JobTitle': 'warehouse associate', 'Salary': 74829.0, 'Bonus': 4263.0, 'ID_employee': 7712.0}
# {'JobTitle': 'sales associate', 'Salary': 91342.0, 'Bonus': 4516.0, 'ID_employee': 7713.0}
# {'JobTitle': 'sales associate', 'Salary': 101140.0, 'Bonus': 4851.0, 'ID_employee': 7714.0}
# {'JobTitle': 'marketing associate', 'Salary': 62600.0, 'Bonus': 4300.0, 'ID_employee': 7715.0}
# {'JobTitle': 'software engineer', 'Salary': 65313.0, 'Bonus': 4685.0, 'ID_employee': 7716.0}
# {'JobTitle': 'manager', 'Salary': 123153.0, 'Bonus': 4111.0, 'ID_employee': 7717.0}
# {'JobTitle': 'it', 'Salary': 57500.0, 'Bonus': 3665.0, 'ID_employee': 7718.0}
# {'JobTitle': 'manager', 'Salary': 115604.0, 'Bonus': 4098.0, 'ID_employee': 7719.0}
# {'JobTitle': 'software engineer', 'Salary': 55555.0, 'Bonus': 4390.0, 'ID_employee': 7720.0}
# {'JobTitle': 'data scientist', 'Salary': 124166.0, 'Bonus': 3875.0, 'ID_employee': 7721.0}
# {'JobTitle': 'it', 'Salary': 101050.0, 'Bonus': 3879.0, 'ID_employee': 7722.0}
# {'JobTitle': 'software engineer', 'Salary': 160460.0, 'Bonus': 2930.0, 'ID_employee': 7723.0}
# {'JobTitle': 'financial analyst', 'Salary': 85947.0, 'Bonus': 3909.0, 'ID_employee': 7724.0}
# {'JobTitle': 'graphic designer', 'Salary': 135512.0, 'Bonus': 3955.0, 'ID_employee': 7725.0}
# {'JobTitle': 'financial analyst', 'Salary': 124151.0, 'Bonus': 3392.0, 'ID_employee': 7726.0}
# {'JobTitle': 'manager', 'Salary': 115742.0, 'Bonus': 3661.0, 'ID_employee': 7727.0}
# {'JobTitle': 'it', 'Salary': 93358.0, 'Bonus': 3223.0, 'ID_employee': 7728.0}
# {'JobTitle': 'it', 'Salary': 98995.0, 'Bonus': 4596.0, 'ID_employee': 7729.0}
# {'JobTitle': 'it', 'Salary': 109645.0, 'Bonus': 5472.0, 'ID_employee': 7730.0}
# {'JobTitle': 'financial analyst', 'Salary': 61609.0, 'Bonus': 3738.0, 'ID_employee': 7731.0}
# {'JobTitle': 'data scientist', 'Salary': 122352.0, 'Bonus': 3590.0, 'ID_employee': 7732.0}
# {'JobTitle': 'software engineer', 'Salary': 86650.0, 'Bonus': 3518.0, 'ID_employee': 7733.0}
# {'JobTitle': 'data scientist', 'Salary': 101284.0, 'Bonus': 4993.0, 'ID_employee': 7734.0}
# {'JobTitle': 'manager', 'Salary': 119794.0, 'Bonus': 3712.0, 'ID_employee': 7735.0}
# {'JobTitle': 'graphic designer', 'Salary': 96609.0, 'Bonus': 3044.0, 'ID_employee': 7736.0}
# {'JobTitle': 'financial analyst', 'Salary': 84725.0, 'Bonus': 3274.0, 'ID_employee': 7737.0}
# {'JobTitle': 'driver', 'Salary': 59493.0, 'Bonus': 3955.0, 'ID_employee': 7738.0}
# {'JobTitle': 'manager', 'Salary': 131980.0, 'Bonus': 3841.0, 'ID_employee': 7739.0}
# {'JobTitle': 'data scientist', 'Salary': 78836.0, 'Bonus': 3588.0, 'ID_employee': 7740.0}
# {'JobTitle': 'driver', 'Salary': 112719.0, 'Bonus': 3382.0, 'ID_employee': 7741.0}
# {'JobTitle': 'driver', 'Salary': 103328.0, 'Bonus': 4543.0, 'ID_employee': 7742.0}
# {'JobTitle': 'financial analyst', 'Salary': 68643.0, 'Bonus': 4674.0, 'ID_employee': 7743.0}
# {'JobTitle': 'sales associate', 'Salary': 67296.0, 'Bonus': 4780.0, 'ID_employee': 7744.0}
# {'JobTitle': 'driver', 'Salary': 116803.0, 'Bonus': 3431.0, 'ID_employee': 7745.0}
# {'JobTitle': 'software engineer', 'Salary': 86375.0, 'Bonus': 3368.0, 'ID_employee': 7746.0}
# {'JobTitle': 'it', 'Salary': 49449.0, 'Bonus': 4149.0, 'ID_employee': 7747.0}
# {'JobTitle': 'software engineer', 'Salary': 118282.0, 'Bonus': 3599.0, 'ID_employee': 7748.0}
# {'JobTitle': 'it', 'Salary': 85648.0, 'Bonus': 2728.0, 'ID_employee': 7749.0}
# {'JobTitle': 'manager', 'Salary': 179726.0, 'Bonus': 4284.0, 'ID_employee': 7750.0}
# {'JobTitle': 'financial analyst', 'Salary': 108719.0, 'Bonus': 4143.0, 'ID_employee': 7751.0}
# {'JobTitle': 'it', 'Salary': 109832.0, 'Bonus': 3528.0, 'ID_employee': 7752.0}
# {'JobTitle': 'software engineer', 'Salary': 127250.0, 'Bonus': 4263.0, 'ID_employee': 7753.0}
# {'JobTitle': 'software engineer', 'Salary': 81547.0, 'Bonus': 3510.0, 'ID_employee': 7754.0}
# {'JobTitle': 'data scientist', 'Salary': 95798.0, 'Bonus': 2530.0, 'ID_employee': 7755.0}
# {'JobTitle': 'manager', 'Salary': 124782.0, 'Bonus': 4618.0, 'ID_employee': 7756.0}
# {'JobTitle': 'warehouse associate', 'Salary': 126256.0, 'Bonus': 3463.0, 'ID_employee': 7757.0}
# {'JobTitle': 'software engineer', 'Salary': 124660.0, 'Bonus': 2200.0, 'ID_employee': 7758.0}
# {'JobTitle': 'data scientist', 'Salary': 128730.0, 'Bonus': 3247.0, 'ID_employee': 7759.0}
# {'JobTitle': 'manager', 'Salary': 136836.0, 'Bonus': 4070.0, 'ID_employee': 7760.0}
# {'JobTitle': 'it', 'Salary': 89272.0, 'Bonus': 2600.0, 'ID_employee': 7761.0}
# {'JobTitle': 'software engineer', 'Salary': 93855.0, 'Bonus': 4099.0, 'ID_employee': 7762.0}
# {'JobTitle': 'graphic designer', 'Salary': 36642.0, 'Bonus': 4388.0, 'ID_employee': 7763.0}
# {'JobTitle': 'sales associate', 'Salary': 112604.0, 'Bonus': 3366.0, 'ID_employee': 7764.0}
# {'JobTitle': 'data scientist', 'Salary': 123333.0, 'Bonus': 3353.0, 'ID_employee': 7765.0}
# {'JobTitle': 'it', 'Salary': 105771.0, 'Bonus': 2978.0, 'ID_employee': 7766.0}
# {'JobTitle': 'financial analyst', 'Salary': 99643.0, 'Bonus': 3789.0, 'ID_employee': 7767.0}
# {'JobTitle': 'sales associate', 'Salary': 92468.0, 'Bonus': 3242.0, 'ID_employee': 7768.0}
# {'JobTitle': 'it', 'Salary': 91447.0, 'Bonus': 3196.0, 'ID_employee': 7769.0}
# {'JobTitle': 'warehouse associate', 'Salary': 45915.0, 'Bonus': 4765.0, 'ID_employee': 7770.0}
# {'JobTitle': 'sales associate', 'Salary': 113031.0, 'Bonus': 3409.0, 'ID_employee': 7771.0}
# {'JobTitle': 'software engineer', 'Salary': 132815.0, 'Bonus': 3367.0, 'ID_employee': 7772.0}
# {'JobTitle': 'manager', 'Salary': 110078.0, 'Bonus': 1703.0, 'ID_employee': 7773.0}
# {'JobTitle': 'data scientist', 'Salary': 106918.0, 'Bonus': 3180.0, 'ID_employee': 7774.0}
# {'JobTitle': 'software engineer', 'Salary': 106045.0, 'Bonus': 3079.0, 'ID_employee': 7775.0}
# {'JobTitle': 'warehouse associate', 'Salary': 107479.0, 'Bonus': 2051.0, 'ID_employee': 7776.0}
# {'JobTitle': 'software engineer', 'Salary': 109606.0, 'Bonus': 2193.0, 'ID_employee': 7777.0}
# {'JobTitle': 'sales associate', 'Salary': 88195.0, 'Bonus': 2375.0, 'ID_employee': 7778.0}
# {'JobTitle': 'it', 'Salary': 92950.0, 'Bonus': 2125.0, 'ID_employee': 7779.0}
# {'JobTitle': 'sales associate', 'Salary': 82164.0, 'Bonus': 2611.0, 'ID_employee': 7780.0}
# {'JobTitle': 'software engineer', 'Salary': 119069.0, 'Bonus': 2788.0, 'ID_employee': 7781.0}
# {'JobTitle': 'manager', 'Salary': 120574.0, 'Bonus': 2683.0, 'ID_employee': 7782.0}
# {'JobTitle': 'data scientist', 'Salary': 97311.0, 'Bonus': 3083.0, 'ID_employee': 7783.0}
# {'JobTitle': 'sales associate', 'Salary': 102593.0, 'Bonus': 1823.0, 'ID_employee': 7784.0}
# {'JobTitle': 'data scientist', 'Salary': 108977.0, 'Bonus': 3567.0, 'ID_employee': 7785.0}
# {'JobTitle': 'financial analyst', 'Salary': 92347.0, 'Bonus': 2724.0, 'ID_employee': 7786.0}
# {'JobTitle': 'financial analyst', 'Salary': 97376.0, 'Bonus': 2225.0, 'ID_employee': 7787.0}
# {'JobTitle': 'financial analyst', 'Salary': 123108.0, 'Bonus': 2244.0, 'ID_employee': 7788.0}

# %%
pd.DataFrame(transformed_data)
# Out:
#       id    Bonus
# 0   6789   9938.0
# 1   6790   9268.0
# 2   6791  10126.0
# 3   6792  10541.0
# 4   6793   9836.0
# ..   ...      ...
# 94  6886   7567.0
# 95  6887   7169.0
# 96  6888   7392.0
# 97  6889   7285.0
# 98  6890   7513.0
#
# [99 rows x 2 columns]
